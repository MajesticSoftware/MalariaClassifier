# %% [markdown]
# # Malaria Classifier

# %%
import tensorflow as tf
import cv2
import numpy as np
import random
import os
import random
import string

# %%
from tensorflow.keras.preprocessing.image import load_img
from tensorflow.keras.preprocessing.image import img_to_array
from tensorflow.keras.preprocessing.image import array_to_img

# %%
img0 = load_img('/Users/jeffreyscruggs/Desktop/A.I. Projects/cell_images/Parasitized/C33P1thinF_IMG_20150619_120645a_cell_216.png', target_size=(28, 28, 3))
target_size=(28, 28, 3)

# %%
img0
# Out:
# <PIL.Image.Image image mode=RGB size=28x28 at 0x6481AD910>

# %%
img_array = img_to_array(img0)

# %%
img_array.shape
# Out:
# (28, 28, 3)

# %%
import glob

# %%
file_path = '/Users/jeffreyscruggs/Desktop/A.I. Projects/cell_images/Uninfected/'
f_names = glob.glob(file_path + '*.png')

# %%
img_array.shape
print(f_names)
# Out:
# ['/Users/jeffreyscruggs/Desktop/A.I. Projects/cell_images/Uninfected/C13NThinF_IMG_20150614_131318_cell_179.png', '/Users/jeffreyscruggs/Desktop/A.I. Projects/cell_images/Uninfected/C205ThinF_IMG_20151106_152003_cell_21.png', '/Users/jeffreyscruggs/Desktop/A.I. Projects/cell_images/Uninfected/C230ThinF_IMG_20151112_150647_cell_1.png', '/Users/jeffreyscruggs/Desktop/A.I. Projects/cell_images/Uninfected/C134P95ThinF_IMG_20151005_121834_cell_65.png', '/Users/jeffreyscruggs/Desktop/A.I. Projects/cell_images/Uninfected/C141P102ThinF_IMG_20151005_214836_cell_132.png', '/Users/jeffreyscruggs/Desktop/A.I. Projects/cell_images/Uninfected/C167P128ReThinF_IMG_20151201_105559_cell_61.png', '/Users/jeffreyscruggs/Desktop/A.I. Projects/cell_images/Uninfected/C218ThinF_IMG_20151106_144337_cell_57.png', '/Users/jeffreyscruggs/Desktop/A.I. Projects/cell_images/Uninfected/C182P143NThinF_IMG_20151201_171950_cell_93.png', '/Users/jeffreyscruggs/Desktop/A.I. Projects/cell_images/Uninfected/C181P142ThinF_IMG_20151127_160616_cell_54.png', '/Users/jeffreyscruggs/Desktop/A.I. Projects/cell_images/Uninfected/C142P103ThinF_IMG_20151005_223257_cell_18.png', '/Users/jeffreyscruggs/Desktop/A.I. Projects/cell_images/Uninfected/C80P41ThinF_IMG_20150817_110608_cell_62.png', '/Users/jeffreyscruggs/Desktop/A.I. Projects/cell_images/Uninfected/C144P105ThinF_IMG_20151015_163142_cell_66.png', '/Users/jeffreyscruggs/Desktop/A.I. Projects/cell_images/Uninfected/C12NThinF_IMG_20150614_124212_cell_187.png', '/Users/jeffreyscruggs/Desktop/A.I. Projects/cell_images/Uninfected/C223ThinF_IMG_20151112_104708_cell_190.png', '/Users/jeffreyscruggs/Desktop/A.I. Projects/cell_images/Uninfected/C143P104ThinF_IMG_20151005_225746_cell_133.png', '/Users/jeffreyscruggs/Desktop/A.I. Projects/cell_images/Uninfected/C84P45ThinF_IMG_20150818_101056_cell_87.png', '/Users/jeffreyscruggs/Desktop/A.I. Projects/cell_images/Uninfected/C162P123ThinF_IMG_20151116_105019_cell_23.png', '/Users/jeffreyscruggs/Desktop/A.I. Projects/cell_images/Uninfected/C222ThinF_IMG_20151115_150925_cell_127.png', '/Users/jeffreyscruggs/Desktop/A.I. Projects/cell_images/Uninfected/C1_thinF_IMG_20150604_104919_cell_82.png', '/Users/jeffreyscruggs/Desktop/A.I. Projects/cell_images/Uninfected/C150P111ThinF_IMG_20151115_115950_cell_53.png', '/Users/jeffreyscruggs/Desktop/A.I. Projects/cell_images/Uninfected/C170P131ThinF_IMG_20151119_120233_cell_183.png', '/Users/jeffreyscruggs/Desktop/A.I. Projects/cell_images/Uninfected/C13NThinF_IMG_20150614_131529_cell_168.png', '/Users/jeffreyscruggs/Desktop/A.I. Projects/cell_images/Uninfected/C240ThinF_IMG_20151127_115545_cell_205.png', '/Users/jeffreyscruggs/Desktop/A.I. Projects/cell_images/Uninfected/C1_thinF_IMG_20150604_104919_cell_96.png', '/Users/jeffreyscruggs/Desktop/A.I. Projects/cell_images/Uninfected/C150P111ThinF_IMG_20151115_115950_cell_47.png', '/Users/jeffreyscruggs/Desktop/A.I. Projects/cell_images/Uninfected/C141P102ThinF_IMG_20151005_213930_cell_61.png', '/Users/jeffreyscruggs/Desktop/A.I. Projects/cell_images/Uninfected/C143P104ThinF_IMG_20151005_225746_cell_127.png', '/Users/jeffreyscruggs/Desktop/A.I. Projects/cell_images/Uninfected/C160P121ThinF_IMG_20151116_093109_cell_29.png', '/Users/jeffreyscruggs/Desktop/A.I. Projects/cell_images/Uninfected/C82P43ThinF_IMG_20150817_124010_cell_39.png', '/Users/jeffreyscruggs/Desktop/A.I. Projects/cell_images/Uninfected/C169P130ThinF_IMG_20151118_163539_cell_148.png', '/Users/jeffreyscruggs/Desktop/A.I. Projects/cell_images/Uninfected/C78P39ThinF_IMG_20150606_103630_cell_3.png', '/Users/jeffreyscruggs/Desktop/A.I. Projects/cell_images/Uninfected/C239ThinF_IMG_20151127_113253_cell_25.png', '/Users/jeffreyscruggs/Desktop/A.I. Projects/cell_images/Uninfected/C58P19thinF_IMG_20150802_122338_cell_86.png', '/Users/jeffreyscruggs/Desktop/A.I. Projects/cell_images/Uninfected/C98P59ThinF_IMG_20150917_153311_cell_73.png', '/Users/jeffreyscruggs/Desktop/A.I. Projects/cell_images/Uninfected/C109P70ThinF_IMG_20150930_102944_cell_ ...

# %%
imgs = []
for i in range(len(f_names)):  # f_names
    img = load_img(f_names[i], target_size=(28, 28, 3))  # read img
    arr_img = img_to_array(img)  # img to array
    arr_img = np.expand_dims(arr_img, axis=0)   # add one dim for batch
    imgs.append(arr_img) # append imgs to list
    print("loading no.%s image."%i)
x0 = np.concatenate([x for x in imgs]) # concatenate imgs
# Out:
# loading no.0 image.
# loading no.1 image.
# loading no.2 image.
# loading no.3 image.
# loading no.4 image.
# loading no.5 image.
# loading no.6 image.
# loading no.7 image.
# loading no.8 image.
# loading no.9 image.
# loading no.10 image.
# loading no.11 image.
# loading no.12 image.
# loading no.13 image.
# loading no.14 image.
# loading no.15 image.
# loading no.16 image.
# loading no.17 image.
# loading no.18 image.
# loading no.19 image.
# loading no.20 image.
# loading no.21 image.
# loading no.22 image.
# loading no.23 image.
# loading no.24 image.
# loading no.25 image.
# loading no.26 image.
# loading no.27 image.
# loading no.28 image.
# loading no.29 image.
# loading no.30 image.
# loading no.31 image.
# loading no.32 image.
# loading no.33 image.
# loading no.34 image.
# loading no.35 image.
# loading no.36 image.
# loading no.37 image.
# loading no.38 image.
# loading no.39 image.
# loading no.40 image.
# loading no.41 image.
# loading no.42 image.
# loading no.43 image.
# loading no.44 image.
# loading no.45 image.
# loading no.46 image.
# loading no.47 image.
# loading no.48 image.
# loading no.49 image.
# loading no.50 image.
# loading no.51 image.
# loading no.52 image.
# loading no.53 image.
# loading no.54 image.
# loading no.55 image.
# loading no.56 image.
# loading no.57 image.
# loading no.58 image.
# loading no.59 image.
# loading no.60 image.
# loading no.61 image.
# loading no.62 image.
# loading no.63 image.
# loading no.64 image.
# loading no.65 image.
# loading no.66 image.
# loading no.67 image.
# loading no.68 image.
# loading no.69 image.
# loading no.70 image.
# loading no.71 image.
# loading no.72 image.
# loading no.73 image.
# loading no.74 image.
# loading no.75 image.
# loading no.76 image.
# loading no.77 image.
# loading no.78 image.
# loading no.79 image.
# loading no.80 image.
# loading no.81 image.
# loading no.82 image.
# loading no.83 image.
# loading no.84 image.
# loading no.85 image.
# loading no.86 image.
# loading no.87 image.
# loading no.88 image.
# loading no.89 image.
# loading no.90 image.
# loading no.91 image.
# loading no.92 image.
# loading no.93 image.
# loading no.94 image.
# loading no.95 image.
# loading no.96 image.
# loading no.97 image.
# loading no.98 image.
# loading no.99 image.
# loading no.100 image.
# loading no.101 image.
# loading no.102 image.
# loading no.103 image.
# loading no.104 image.
# loading no.105 image.
# loading no.106 image.
# loading no.107 image.
# loading no.108 image.
# loading no.109 image.
# loading no.110 image.
# loading no.111 image.
# loading no.112 image.
# loading no.113 image.
# loading no.114 image.
# loading no.115 image.
# loading no.116 image.
# loading no.117 image.
# loading no.118 image.
# loading no.119 image.
# loading no.120 image.
# loading no.121 image.
# loading no.122 image.
# loading no.123 image.
# loading no.124 image.
# loading no.125 image.
# loading no.126 image.
# loading no.127 image.
# loading no.128 image.
# loading no.129 image.
# loading no.130 image.
# loading no.131 image.
# loading no.132 image.
# loading no.133 image.
# loading no.134 image.
# loading no.135 image.
# loading no.136 image.
# loading no.137 image.
# loading no.138 image.
# loading no.139 image.
# loading no.140 image.
# loading no.141 image.
# loading no.142 image.
# loading no.143 image.
# loading no.144 image.
# loading no.145 image.
# loading no.146 image.
# loading no.147 image.
# loading no.148 image.
# loading no.149 image.
# loading no.150 image.
# loading no.151 image.
# loading no.152 image.
# loading no.153 image.
# loading no.154 image.
# loading no.155 image.
# loading no.156 image.
# loading no.157 image.
# loading no.158 image.
# loading no.159 image.
# loading no.160 image.
# loading no.161 image.
# loading no.162 image.
# loading no.163 image.
# loading no.164 image.
# loading no.165 image.
# loading no.166 image.
# loading no.167 image.
# loading no.168 image.
# loading no.169 image.
# loading no.170 image.
# loading no.171 image.
# loading no.172 image.
# loading no.173 image.
# loading no.174 image.
# loading no.175 image.
# loading no.176 image.
# loading no.177 image.
# loading no.178 image.
# loading no.179 image.
# loading no.180 image.
# loading no.181 image.
# loading no.182 image.
# loading no.183 image.
# loading no.184 image.
# loading no.185 image.
# loading no.186 image.
# loading no.187 image.
# loading no.188 image.
# loading no.189 image.
# loading no.190 image.
# loading no.191 image.
# loading no.192 image.
# loading no.193 image.
# loading no.194 image.
# loading no.195 image.
# loading no.196 image.
# loading no.197 image.
# loading no.198 image.
# loading no.199 image.
# loading no.200 image.
# loading no.201 image.
# loading no.202 image.
# loading no.203 image.
# loading no.204 image.
# loading no.205 image.
# loading no.206 image.
# loading no.207 image.
# loading no.208 image.
# loading no.209 image.
# loading no.210 image.
# loading no.211 image.
# loading no.212 image.
# loading no.213 image.
# loading no.214 image.
# loading no.215 image.
# loading no.216 image.
# loading no.217 image.
# loading no.218 image.
# loading no.219 image.
# loading no.220 image.
# loading no.221 image.
# loading no.222 image.
# loading no.223 image.
# loading no.224 image.
# loading no.225 image.
# loading no.226 image.
# loading no.227 image.
# loading no.228 image.
# loading no.229 image.
# loading no.230 image.
# loading no.231 image.
# loading no.232 image.
# loading no.233 image.
# loading no.234 image.
# loading no.235 image.
# loading no.236 image.
# loading no.237 image.
# loading no.238 image.
# loading no.239 image.
# loading no.240 image.
# loading no.241 image.
# loading no.242 image.
# loading no.243 image.
# loading no.244 image.
# loading no.245 image.
# loading no.246 image.
# loading no.247 image.
# loading no.248 image.
# loading no.249 image.
# loading no.250 image.
# loading no.251 image.
# loading no.252 image.
# loading no.253 image.
# loading no.254 image.
# loading no.255 image.
# loading no.256 image.
# loading no.257 image.
# loading no.258 image.
# loading no.259 image.
# loading no.260 image.
# loading no.261 image.
# loading no.262 image.
# loading no.263 image.
# loading no.264 image.
# loading no.265 image.
# loading no.266 image.
# loading no.267 image.
# loading no.268 image.
# loading no.269 image.
# loading no.270 image.
# loading no.271 image.
# loading no.272 image.
# loading no.273 image.
# loading no.274 image.
# loading no.275 image.
# loading no.276 image.
# loading no.277 image.
# loading no.278 image.
# loading no.279 image.
# loading no.280 image.
# loading no.281 image.
# loading no.282 image.
# loading no.283 image.
# loading no.284 image.
# loading no.285 image.
# loading no.286 image.
# loading no.287 image.
# loading no.288 image.
# loading no.289 image.
# loading no.290 image.
# loading no.291 image.
# loading no.292 image.
# loading no.293 image.
# loading no.294 image.
# loading no.295 image.
# loading no.296 image.
# loading no.297 image.
# loading no.298 image.
# loading no.299 image.
# loading no.300 image.
# loading no.301 image.
# loading no.302 image.
# loading no.303 image.
# loading no.304 image.
# loading no.305 image.
# loading no.306 image.
# loading no.307 image.
# loading no.308 image.
# loading no.309 image.
# loading no.310 image.
# loading no.311 image.
# loading no.312 image.
# loading no.313 image.
# loading no.314 image.
# loading no.315 image.
# loading no.316 image.
# loading no.317 image.
# loading no.318 image.
# loading no.319 image.
# loading no.320 image.
# loading no.321 image.
# loading no.322 image.
# loading no.323 image.
# loading no.324 image.
# loading no.325 image.
# loading no.326 image.
# loading no.327 image.
# loading no.328 image.
# loading no.329 image.
# loading no.330 image.
# loading no.331 image.
# loading no.332 image.
# loading no.333 image.
# loading no.334 image.
# loading no.335 image.
# loading no.336 image.
# loading no.337 image.
# loading no.338 image.
# loading no.339 image.
# loading no.340 image.
# loading no.341 image.
# loading no.342 image.
# loading no.343 image.
# loading no.344 image.
# loading no.345 image.
# loading no.346 image.
# loading no.347 image.
# loading no.348 image.
# loading no.349 image.
# loading no.350 image.
# loading no.351 image.
# loading no.352 image.
# loading no.353 image.
# loading no.354 image.
# loading no.355 image.
# loading no.356 image.
# loading no.357 image.
# loading no.358 image.
# loading no.359 image.
# loading no.360 image.
# loading no.361 image.
# loading no.362 image.
# loading no.363 image.
# loading no.364 image.
# loading no.365 image.
# loading no.366 image.
# loading no.367 image.
# loading no.368 image.
# loading no.369 image.
# loading no.370 image.
# loading no.371 image.
# loading no.372 image.
# loading no.373 image.
# loading no.374 image.
# loading no.375 image.
# loading no.376 image.
# loading no.377 image.
# loading no.378 image.
# loading no.379 image.
# loading no.380 image.
# loading no.381 image.
# loading no.382 image.
# loading no.383 image.
# loading no.384 image.
# loading no.385 image.
# loading no.386 image.
# loading no.387 image.
# loading no.388 image.
# loading no.389 image.
# loading no.390 image.
# loading no.391 image.
# loading no.392 image.
# loading no.393 image.
# loading no.394 image.
# loading no.395 image.
# loading no.396 image.
# loading no.397 image.
# loading no.398 image.
# loading no.399 image.
# loading no.400 image.
# loading no.401 image.
# loading no.402 image.
# loading no.403 image.
# loading no.404 image.
# loading no.405 image.
# loading no.406 image.
# loading no.407 image.
# loading no.408 image.
# loading no.409 image.
# loading no.410 image.
# loading no.411 image.
# loading no.412 image.
# loading no.413 image.
# loading no.414 image.
# loading no.415 image.
# loading no.416 image.
# loading no.417 image.
# loading no.418 image.
# loading no.419 image.
# loading no.420 image.
# loading no.421 image.
# loading no.422 image.
# loading no.423 image.
# loading no.424 image.
# loading no.425 image.
# loading no.426 image.
# loading no.427 image.
# loading no.428 image.
# loading no.429 image.
# loading no.430 image.
# loading no.431 image.
# loading no.432 image.
# loading no.433 image.
# loading no.434 image.
# loading no.435 image.
# loading no.436 image.
# loading no.437 image.
# loading no.438 image.
# loading no.439 image.
# loading no.440 image.
# loading no.441 image.
# loading no.442 image.
# loading no.443 image.
# loading no.444 image.
# loading no.445 image.
# loading no.446 image.
# loading no.447 image.
# loading no.448 image.
# loading no.449 image.
# loading no.450 image.
# loading no.451 image.
# loading no.452 image.
# loading no.453 image.
# loading no.454 image.
# loading no.455 image.
# loading no.456 image.
# loading no.457 image.
# loading no.458 image.
# loading no.459 image.
# loading no.460 image.
# loading no.461 image.
# loading no.462 image.
# loading no.463 image.
# loading no.464 image.
# loading no.465 image.
# loading no.466 image.
# loading no.467 image.
# loading no.468 image.
# loading no.469 image.
# loading no.470 image.
# loading no.471 image.
# loading no.472 image.
# loading no.473 image.
# loading no.474 image.
# loading no.475 image.
# loading no.476 image.
# loading no.477 image.
# loading no.478 image.
# loading no.479 image.
# loading no.480 image.
# loading no.481 image.
# loading no.482 image.
# loading no.483 image.
# loading no.484 image.
# loading no.485 image.
# loading no.486 image.
# loading no.487 image.
# loading no.488 image.
# loading no.489 image.
# loading no.490 image.
# loading no.491 image.
# loading no.492 image.
# loading no.493 image.
# loading no.494 image.
# loading no.495 image.
# loading no.496 image.
# loading no.497 image.
# loading no.498 image.
# loading no.499 image.
# loading no.500 image.
# loading no.501 image.
# loading no.502 image.
# loading no.503 image.
# loading no.504 image.
# loading no.505 image.
# loading no.506 image.
# loading no.507 image.
# loading no.508 image.
# loading no.509 image.
# loading no.510 image.
# loading no.511 image.
# loading no.512 image.
# loading no.513 image.
# loading no.514 image.
# loading no.515 image.
# loading no.516 image.
# loading no.517 image.
# loading no.518 image.
# loading no.519 image.
# loading no.520 image.
# loading no.521 image.
# loading no.522 image.
# loading no.523 image.
# loading no.524 image.
# loading no.525 image.
# loading no.526 image.
# loading no.527 image.
# loading no.528 image.
# loading no.529 image.
# loading no.530 image.
# loading no.531 image.
# loading no.532 image.
# loading no.533 image.
# loading no.534 image.
# loading no.535 image.
# loading no.536 image.
# loading no.537 image.
# loading no.538 image.
# loading no.539 image.
# loading no.540 image.
# loading no.541 image.
# loading no.542 image.
# loading no.543 image.
# loading no.544 image.
# loading no.545 image.
# loading no.546 image.
# loading no.547 image.
# loading no.548 image.
# loading no.549 image.
# loading no.550 image.
# loading no.551 image.
# loading no.552 image.
# loading no.553 image.
# loading no.554 image.
# loading no.555 image.
# loading no.556 image.
# loading no.557 image.
# loading no.558 image.
# loading no.559 image.
# loading no.560 image.
# loading no.561 image.
# loading no.562 image.
# loading no.563 image.
# loading no.564 image.
# loading no.565 image.
# loading no.566 image.
# loading no.567 image.
# loading no.568 image.
# loading no.569 image.
# loading no.570 image.
# loading no.571 image.
# loading no.572 image.
# loading no.573 image.
# loading no.574 image.
# loading no.575 image.
# loading no.576 image.
# loading no.577 image.
# loading no.578 image.
# loading no.579 image.
# loading no.580 image.
# loading no.581 image.
# loading no.582 image.
# loading no.583 image.
# loading no.584 image.
# loading no.585 image.
# loading no.586 image.
# loading no.587 image.
# loading no.588 image.
# loading no.589 image.
# loading no.590 image.
# loading no.591 image.
# loading no.592 image.
# loading no.593 image.
# loading no.594 image.
# loading no.595 image.
# loading no.596 image.
# loading no.597 image.
# loading no.598 image.
# loading no.599 image.
# loading no.600 image.
# loading no.601 image.
# loading no.602 image.
# loading no.603 image.
# loading no.604 image.
# loading no.605 image.
# loading no.606 image.
# loading no.607 image.
# loading no.608 image.
# loading no.609 image.
# loading no.610 image.
# loading no.611 image.
# loading no.612 image.
# loading no.613 image.
# loading no.614 image.
# loading no.615 image.
# loading no.616 image.
# loading no.617 image.
# loading no.618 image.
# loading no.619 image.
# loading no.620 image.
# loading no.621 image.
# loading no.622 image.
# loading no.623 image.
# loading no.624 image.
# loading no.625 image.
# loading no.626 image.
# loading no.627 image.
# loading no.628 image.
# loading no.629 image.
# loading no.630 image.
# loading no.631 image.
# loading no.632 image.
# loading no.633 image.
# loading no.634 image.
# loading no.635 image.
# loading no.636 image.
# loading no.637 image.
# loading no.638 image.
# loading no.639 image.
# loading no.640 image.
# loading no.641 image.
# loading no.642 image.
# loading no.643 image.
# loading no.644 image.
# loading no.645 image.
# loading no.646 image.
# loading no.647 image.
# loading no.648 image.
# loading no.649 image.
# loading no.650 image.
# loading no.651 image.
# loading no.652 image.
# loading no.653 image.
# loading no.654 image.
# loading no.655 image.
# loading no.656 image.
# loading no.657 image.
# loading no.658 image.
# loading no.659 image.
# loading no.660 image.
# loading no.661 image.
# loading no.662 image.
# loading no.663 image.
# loading no.664 image.
# loading no.665 image.
# loading no.666 image.
# loading no.667 image.
# loading no.668 image.
# loading no.669 image.
# loading no.670 image.
# loading no.671 image.
# loading no.672 image.
# loading no.673 image.
# loading no.674 image.
# loading no.675 image.
# loading no.676 image.
# loading no.677 image.
# loading no.678 image.
# loading no.679 image.
# loading no.680 image.
# loading no.681 image.
# loading no.682 image.
# loading no.683 image.
# loading no.684 image.
# loading no.685 image.
# loading no.686 image.
# loading no.687 image.
# loading no.688 image.
# loading no.689 image.
# loading no.690 image.
# loading no.691 image.
# loading no.692 image.
# loading no.693 image.
# loading no.694 image.
# loading no.695 image.
# loading no.696 image.
# loading no.697 image.
# loading no.698 image.
# loading no.699 image.
# loading no.700 image.
# loading no.701 image.
# loading no.702 image.
# loading no.703 image.
# loading no.704 image.
# loading no.705 image.
# loading no.706 image.
# loading no.707 image.
# loading no.708 image.
# loading no.709 image.
# loading no.710 image.
# loading no.711 image.
# loading no.712 image.
# loading no.713 image.
# loading no.714 image.
# loading no.715 image.
# loading no.716 image.
# loading no.717 image.
# loading no.718 image.
# loading no.719 image.
# loading no.720 image.
# loading no.721 image.
# loading no.722 image.
# loading no.723 image.
# loading no.724 image.
# loading no.725 image.
# loading no.726 image.
# loading no.727 image.
# loading no.728 image.
# loading no.729 image.
# loading no.730 image.
# loading no.731 image.
# loading no.732 image.
# loading no.733 image.
# loading no.734 image.
# loading no.735 image.
# loading no.736 image.
# loading no.737 image.
# loading no.738 image.
# loading no.739 image.
# loading no.740 image.
# loading no.741 image.
# loading no.742 image.
# loading no.743 image.
# loading no.744 image.
# loading no.745 image.
# loading no.746 image.
# loading no.747 image.
# loading no.748 image.
# loading no.749 image.
# loading no.750 image.
# loading no.751 image.
# loading no.752 image.
# loading no.753 image.
# loading no.754 image.
# loading no.755 image.
# loading no.756 image.
# loading no.757 image.
# loading no.758 image.
# loading no.759 image.
# loading no.760 image.
# loading no.761 image.
# loading no.762 image.
# loading no.763 image.
# loading no.764 image.
# loading no.765 image.
# loading no.766 image.
# loading no.767 image.
# loading no.768 image.
# loading no.769 image.
# loading no.770 image.
# loading no.771 image.
# loading no.772 image.
# loading no.773 image.
# loading no.774 image.
# loading no.775 image.
# loading no.776 image.
# loading no.777 image.
# loading no.778 image.
# loading no.779 image.
# loading no.780 image.
# loading no.781 image.
# loading no.782 image.
# loading no.783 image.
# loading no.784 image.
# loading no.785 image.
# loading no.786 image.
# loading no.787 image.
# loading no.788 image.
# loading no.789 image.
# loading no.790 image.
# loading no.791 image.
# loading no.792 image.
# loading no.793 image.
# loading no.794 image.
# loading no.795 image.
# loading no.796 image.
# loading no.797 image.
# loading no.798 image.
# loading no.799 image.
# loading no.800 image.
# loading no.801 image.
# loading no.802 image.
# loading no.803 image.
# loading no.804 image.
# loading no.805 image.
# loading no.806 image.
# loading no.807 image.
# loading no.808 image.
# loading no.809 image.
# loading no.810 image.
# loading no.811 image.
# loading no.812 image.
# loading no.813 image.
# loading no.814 image.
# loading no.815 image.
# loading no.816 image.
# loading no.817 image.
# loading no.818 image.
# loading no.819 image.
# loading no.820 image.
# loading no.821 image.
# loading no.822 image.
# loading no.823 image.
# loading no.824 image.
# loading no.825 image.
# loading no.826 image.
# loading no.827 image.
# loading no.828 image.
# loading no.829 image.
# loading no.830 image.
# loading no.831 image.
# loading no.832 image.
# loading no.833 image.
# loading no.834 image.
# loading no.835 image.
# loading no.836 image.
# loading no.837 image.
# loading no.838 image.
# loading no.839 image.
# loading no.840 image.
# loading no.841 image.
# loading no.842 image.
# loading no.843 image.
# loading no.844 image.
# loading no.845 image.
# loading no.846 image.
# loading no.847 image.
# loading no.848 image.
# loading no.849 image.
# loading no.850 image.
# loading no.851 image.
# loading no.852 image.
# loading no.853 image.
# loading no.854 image.
# loading no.855 image.
# loading no.856 image.
# loading no.857 image.
# loading no.858 image.
# loading no.859 image.
# loading no.860 image.
# loading no.861 image.
# loading no.862 image.
# loading no.863 image.
# loading no.864 image.
# loading no.865 image.
# loading no.866 image.
# loading no.867 image.
# loading no.868 image.
# loading no.869 image.
# loading no.870 image.
# loading no.871 image.
# loading no.872 image.
# loading no.873 image.
# loading no.874 image.
# loading no.875 image.
# loading no.876 image.
# loading no.877 image.
# loading no.878 image.
# loading no.879 image.
# loading no.880 image.
# loading no.881 image.
# loading no.882 image.
# loading no.883 image.
# loading no.884 image.
# loading no.885 image.
# loading no.886 image.
# loading no.887 image.
# loading no.888 image.
# loading no.889 image.
# loading no.890 image.
# loading no.891 image.
# loading no.892 image.
# loading no.893 image.
# loading no.894 image.
# loading no.895 image.
# loading no.896 image.
# loading no.897 image.
# loading no.898 image.
# loading no.899 image.
# loading no.900 image.
# loading no.901 image.
# loading no.902 image.
# loading no.903 image.
# loading no.904 image.
# loading no.905 image.
# loading no.906 image.
# loading no.907 image.
# loading no.908 image.
# loading no.909 image.
# loading no.910 image.
# loading no.911 image.
# loading no.912 image.
# loading no.913 image.
# loading no.914 image.
# loading no.915 image.
# loading no.916 image.
# loading no.917 image.
# loading no.918 image.
# loading no.919 image.
# loading no.920 image.
# loading no.921 image.
# loading no.922 image.
# loading no.923 image.
# loading no.924 image.
# loading no.925 image.
# loading no.926 image.
# loading no.927 image.
# loading no.928 image.
# loading no.929 image.
# loading no.930 image.
# loading no.931 image.
# loading no.932 image.
# loading no.933 image.
# loading no.934 image.
# loading no.935 image.
# loading no.936 image.
# loading no.937 image.
# loading no.938 image.
# loading no.939 image.
# loading no.940 image.
# loading no.941 image.
# loading no.942 image.
# loading no.943 image.
# loading no.944 image.
# loading no.945 image.
# loading no.946 image.
# loading no.947 image.
# loading no.948 image.
# loading no.949 image.
# loading no.950 image.
# loading no.951 image.
# loading no.952 image.
# loading no.953 image.
# loading no.954 image.
# loading no.955 image.
# loading no.956 image.
# loading no.957 image.
# loading no.958 image.
# loading no.959 image.
# loading no.960 image.
# loading no.961 image.
# loading no.962 image.
# loading no.963 image.
# loading no.964 image.
# loading no.965 image.
# loading no.966 image.
# loading no.967 image.
# loading no.968 image.
# loading no.969 image.
# loading no.970 image.
# loading no.971 image.
# loading no.972 image.
# loading no.973 image.
# loading no.974 image.
# loading no.975 image.
# loading no.976 image.
# loading no.977 image.
# loading no.978 image.
# loading no.979 image.
# loading no.980 image.
# loading no.981 image.
# loading no.982 image.
# loading no.983 image.
# loading no.984 image.
# loading no.985 image.
# loading no.986 image.
# loading no.987 image.
# loading no.988 image.
# loading no.989 image.
# loading no.990 image.
# loading no.991 image.
# loading no.992 image.
# loading no.993 image.
# loading no.994 image.
# loading no.995 image.
# loading no.996 image.
# loading no.997 image.
# loading no.998 image.
# loading no.999 image.
# loading no.1000 image.
# loading no.1001 image.
# loading no.1002 image.
# loading no.1003 image.
# loading no.1004 image.
# loading no.1005 image.
# loading no.1006 image.
# loading no.1007 image.
# loading no.1008 image.
# loading no.1009 image.
# loading no.1010 image.
# loading no.1011 image.
# loading no.1012 image.
# loading no.1013 image.
# loading no.1014 image.
# loading no.1015 image.
# loading no.1016 image.
# loading no.1017 image.
# loading no.1018 image.
# loading no.1019 image.
# loading no.1020 image.
# loading no.1021 image.
# loading no.1022 image.
# loading no.1023 image.
# loading no.1024 image.
# loading no.1025 image.
# loading no.1026 image.
# loading no.1027 image.
# loading no.1028 image.
# loading no.1029 image.
# loading no.1030 image.
# loading no.1031 image.
# loading no.1032 image.
# loading no.1033 image.
# loading no.1034 image.
# loading no.1035 image.
# loading no.1036 image.
# loading no.1037 image.
# loading no.1038 image.
# loading no.1039 image.
# loading no.1040 image.
# loading no.1041 image.
# loading no.1042 image.
# loading no.1043 image.
# loading no.1044 image.
# loading no.1045 image.
# loading no.1046 image.
# loading no.1047 image.
# loading no.1048 image.
# loading no.1049 image.
# loading no.1050 image.
# loading no.1051 image.
# loading no.1052 image.
# loading no.1053 image.
# loading no.1054 image.
# loading no.1055 image.
# loading no.1056 image.
# loading no.1057 image.
# loading no.1058 image.
# loading no.1059 image.
# loading no.1060 image.
# loading no.1061 image.
# loading no.1062 image.
# loading no.1063 image.
# loading no.1064 image.
# loading no.1065 image.
# loading no.1066 image.
# loading no.1067 image.
# loading no.1068 image.
# loading no.1069 image.
# loading no.1070 image.
# loading no.1071 image.
# loading no.1072 image.
# loading no.1073 image.
# loading no.1074 image.
# loading no.1075 image.
# loading no.1076 image.
# loading no.1077 image.
# loading no.1078 image.
# loading no.1079 image.
# loading no.1080 image.
# loading no.1081 image.
# loading no.1082 image.
# loading no.1083 image.
# loading no.1084 image.
# loading no.1085 image.
# loading no.1086 image.
# loading no.1087 image.
# loading no.1088 image.
# loading no.1089 image.
# loading no.1090 image.
# loading no.1091 image.
# loading no.1092 image.
# loading no.1093 image.
# loading no.1094 image.
# loading no.1095 image.
# loading no.1096 image.
# loading no.1097 image.
# loading no.1098 image.
# loading no.1099 image.
# loading no.1100 image.
# loading no.1101 image.
# loading no.1102 image.
# loading no.1103 image.
# loading no.1104 image.
# loading no.1105 image.
# loading no.1106 image.
# loading no.1107 image.
# loading no.1108 image.
# loading no.1109 image.
# loading no.1110 image.
# loading no.1111 image.
# loading no.1112 image.
# loading no.1113 image.
# loading no.1114 image.
# loading no.1115 image.
# loading no.1116 image.
# loading no.1117 image.
# loading no.1118 image.
# loading no.1119 image.
# loading no.1120 image.
# loading no.1121 image.
# loading no.1122 image.
# loading no.1123 image.
# loading no.1124 image.
# loading no.1125 image.
# loading no.1126 image.
# loading no.1127 image.
# loading no.1128 image.
# loading no.1129 image.
# loading no.1130 image.
# loading no.1131 image.
# loading no.1132 image.
# loading no.1133 image.
# loading no.1134 image.
# loading no.1135 image.
# loading no.1136 image.
# loading no.1137 image.
# loading no.1138 image.
# loading no.1139 image.
# loading no.1140 image.
# loading no.1141 image.
# loading no.1142 image.
# loading no.1143 image.
# loading no.1144 image.
# loading no.1145 image.
# loading no.1146 image.
# loading no.1147 image.
# loading no.1148 image.
# loading no.1149 image.
# loading no.1150 image.
# loading no.1151 image.
# loading no.1152 image.
# loading no.1153 image.
# loading no.1154 image.
# loading no.1155 image.
# loading no.1156 image.
# loading no.1157 image.
# loading no.1158 image.
# loading no.1159 image.
# loading no.1160 image.
# loading no.1161 image.
# loading no.1162 image.
# loading no.1163 image.
# loading no.1164 image.
# loading no.1165 image.
# loading no.1166 image.
# loading no.1167 image.
# loading no.1168 image.
# loading no.1169 image.
# loading no.1170 image.
# loading no.1171 image.
# loading no.1172 image.
# loading no.1173 image.
# loading no.1174 image.
# loading no.1175 image.
# loading no.1176 image.
# loading no.1177 image.
# loading no.1178 image.
# loading no.1179 image.
# loading no.1180 image.
# loading no.1181 image.
# loading no.1182 image.
# loading no.1183 image.
# loading no.1184 image.
# loading no.1185 image.
# loading no.1186 image.
# loading no.1187 image.
# loading no.1188 image.
# loading no.1189 image.
# loading no.1190 image.
# loading no.1191 image.
# loading no.1192 image.
# loading no.1193 image.
# loading no.1194 image.
# loading no.1195 image.
# loading no.1196 image.
# loading no.1197 image.
# loading no.1198 image.
# loading no.1199 image.
# loading no.1200 image.
# loading no.1201 image.
# loading no.1202 image.
# loading no.1203 image.
# loading no.1204 image.
# loading no.1205 image.
# loading no.1206 image.
# loading no.1207 image.
# loading no.1208 image.
# loading no.1209 image.
# loading no.1210 image.
# loading no.1211 image.
# loading no.1212 image.
# loading no.1213 image.
# loading no.1214 image.
# loading no.1215 image.
# loading no.1216 image.
# loading no.1217 image.
# loading no.1218 image.
# loading no.1219 image.
# loading no.1220 image.
# loading no.1221 image.
# loading no.1222 image.
# loading no.1223 image.
# loading no.1224 image.
# loading no.1225 image.
# loading no.1226 image.
# loading no.1227 image.
# loading no.1228 image.
# loading no.1229 image.
# loading no.1230 image.
# loading no.1231 image.
# loading no.1232 image.
# loading no.1233 image.
# loading no.1234 image.
# loading no.1235 image.
# loading no.1236 image.
# loading no.1237 image.
# loading no.1238 image.
# loading no.1239 image.
# loading no.1240 image.
# loading no.1241 image.
# loading no.1242 image.
# loading no.1243 image.
# loading no.1244 image.
# loading no.1245 image.
# loading no.1246 image.
# loading no.1247 image.
# loading no.1248 image.
# loading no.1249 image.
# loading no.1250 image.
# loading no.1251 image.
# loading no.1252 image.
# loading no.1253 image.
# loading no.1254 image.
# loading no.1255 image.
# loading no.1256 image.
# loading no.1257 image.
# loading no.1258 image.
# loading no.1259 image.
# loading no.1260 image.
# loading no.1261 image.
# loading no.1262 image.
# loading no.1263 image.
# loading no.1264 image.
# loading no.1265 image.
# loading no.1266 image.
# loading no.1267 image.
# loading no.1268 image.
# loading no.1269 image.
# loading no.1270 image.
# loading no.1271 image.
# loading no.1272 image.
# loading no.1273 image.
# loading no.1274 image.
# loading no.1275 image.
# loading no.1276 image.
# loading no.1277 image.
# loading no.1278 image.
# loading no.1279 image.
# loading no.1280 image.
# loading no.1281 image.
# loading no.1282 image.
# loading no.1283 image.
# loading no.1284 image.
# loading no.1285 image.
# loading no.1286 image.
# loading no.1287 image.
# loading no.1288 image.
# loading no.1289 image.
# loading no.1290 image.
# loading no.1291 image.
# loading no.1292 image.
# loading no.1293 image.
# loading no.1294 image.
# loading no.1295 image.
# loading no.1296 image.
# loading no.1297 image.
# loading no.1298 image.
# loading no.1299 image.
# loading no.1300 image.
# loading no.1301 image.
# loading no.1302 image.
# loading no.1303 image.
# loading no.1304 image.
# loading no.1305 image.
# loading no.1306 image.
# loading no.1307 image.
# loading no.1308 image.
# loading no.1309 image.
# loading no.1310 image.
# loading no.1311 image.
# loading no.1312 image.
# loading no.1313 image.
# loading no.1314 image.
# loading no.1315 image.
# loading no.1316 image.
# loading no.1317 image.
# loading no.1318 image.
# loading no.1319 image.
# loading no.1320 image.
# loading no.1321 image.
# loading no.1322 image.
# loading no.1323 image.
# loading no.1324 image.
# loading no.1325 image.
# loading no.1326 image.
# loading no.1327 image.
# loading no.1328 image.
# loading no.1329 image.
# loading no.1330 image.
# loading no.1331 image.
# loading no.1332 image.
# loading no.1333 image.
# loading no.1334 image.
# loading no.1335 image.
# loading no.1336 image.
# loading no.1337 image.
# loading no.1338 image.
# loading no.1339 image.
# loading no.1340 image.
# loading no.1341 image.
# loading no.1342 image.
# loading no.1343 image.
# loading no.1344 image.
# loading no.1345 image.
# loading no.1346 image.
# loading no.1347 image.
# loading no.1348 image.
# loading no.1349 image.
# loading no.1350 image.
# loading no.1351 image.
# loading no.1352 image.
# loading no.1353 image.
# loading no.1354 image.
# loading no.1355 image.
# loading no.1356 image.
# loading no.1357 image.
# loading no.1358 image.
# loading no.1359 image.
# loading no.1360 image.
# loading no.1361 image.
# loading no.1362 image.
# loading no.1363 image.
# loading no.1364 image.
# loading no.1365 image.
# loading no.1366 image.
# loading no.1367 image.
# loading no.1368 image.
# loading no.1369 image.
# loading no.1370 image.
# loading no.1371 image.
# loading no.1372 image.
# loading no.1373 image.
# loading no.1374 image.
# loading no.1375 image.
# loading no.1376 image.
# loading no.1377 image.
# loading no.1378 image.
# loading no.1379 image.
# loading no.1380 image.
# loading no.1381 image.
# loading no.1382 image.
# loading no.1383 image.
# loading no.1384 image.
# loading no.1385 image.
# loading no.1386 image.
# loading no.1387 image.
# loading no.1388 image.
# loading no.1389 image.
# loading no.1390 image.
# loading no.1391 image.
# loading no.1392 image.
# loading no.1393 image.
# loading no.1394 image.
# loading no.1395 image.
# loading no.1396 image.
# loading no.1397 image.
# loading no.1398 image.
# loading no.1399 image.
# loading no.1400 image.
# loading no.1401 image.
# loading no.1402 image.
# loading no.1403 image.
# loading no.1404 image.
# loading no.1405 image.
# loading no.1406 image.
# loading no.1407 image.
# loading no.1408 image.
# loading no.1409 image.
# loading no.1410 image.
# loading no.1411 image.
# loading no.1412 image.
# loading no.1413 image.
# loading no.1414 image.
# loading no.1415 image.
# loading no.1416 image.
# loading no.1417 image.
# loading no.1418 image.
# loading no.1419 image.
# loading no.1420 image.
# loading no.1421 image.
# loading no.1422 image.
# loading no.1423 image.
# loading no.1424 image.
# loading no.1425 image.
# loading no.1426 image.
# loading no.1427 image.
# loading no.1428 image.
# loading no.1429 image.
# loading no.1430 image.
# loading no.1431 image.
# loading no.1432 image.
# loading no.1433 image.
# loading no.1434 image.
# loading no.1435 image.
# loading no.1436 image.
# loading no.1437 image.
# loading no.1438 image.
# loading no.1439 image.
# loading no.1440 image.
# loading no.1441 image.
# loading no.1442 image.
# loading no.1443 image.
# loading no.1444 image.
# loading no.1445 image.
# loading no.1446 image.
# loading no.1447 image.
# loading no.1448 image.
# loading no.1449 image.
# loading no.1450 image.
# loading no.1451 image.
# loading no.1452 image.
# loading no.1453 image.
# loading no.1454 image.
# loading no.1455 image.
# loading no.1456 image.
# loading no.1457 image.
# loading no.1458 image.
# loading no.1459 image.
# loading no.1460 image.
# loading no.1461 image.
# loading no.1462 image.
# loading no.1463 image.
# loading no.1464 image.
# loading no.1465 image.
# loading no.1466 image.
# loading no.1467 image.
# loading no.1468 image.
# loading no.1469 image.
# loading no.1470 image.
# loading no.1471 image.
# loading no.1472 image.
# loading no.1473 image.
# loading no.1474 image.
# loading no.1475 image.
# loading no.1476 image.
# loading no.1477 image.
# loading no.1478 image.
# loading no.1479 image.
# loading no.1480 image.
# loading no.1481 image.
# loading no.1482 image.
# loading no.1483 image.
# loading no.1484 image.
# loading no.1485 image.
# loading no.1486 image.
# loading no.1487 image.
# loading no.1488 image.
# loading no.1489 image.
# loading no.1490 image.
# loading no.1491 image.
# loading no.1492 image.
# loading no.1493 image.
# loading no.1494 image.
# loading no.1495 image.
# loading no.1496 image.
# loading no.1497 image.
# loading no.1498 image.
# loading no.1499 image.
# loading no.1500 image.
# loading no.1501 image.
# loading no.1502 image.
# loading no.1503 image.
# loading no.1504 image.
# loading no.1505 image.
# loading no.1506 image.
# loading no.1507 image.
# loading no.1508 image.
# loading no.1509 image.
# loading no.1510 image.
# loading no.1511 image.
# loading no.1512 image.
# loading no.1513 image.
# loading no.1514 image.
# loading no.1515 image.
# loading no.1516 image.
# loading no.1517 image.
# loading no.1518 image.
# loading no.1519 image.
# loading no.1520 image.
# loading no.1521 image.
# loading no.1522 image.
# loading no.1523 image.
# loading no.1524 image.
# loading no.1525 image.
# loading no.1526 image.
# loading no.1527 image.
# loading no.1528 image.
# loading no.1529 image.
# loading no.1530 image.
# loading no.1531 image.
# loading no.1532 image.
# loading no.1533 image.
# loading no.1534 image.
# loading no.1535 image.
# loading no.1536 image.
# loading no.1537 image.
# loading no.1538 image.
# loading no.1539 image.
# loading no.1540 image.
# loading no.1541 image.
# loading no.1542 image.
# loading no.1543 image.
# loading no.1544 image.
# loading no.1545 image.
# loading no.1546 image.
# loading no.1547 image.
# loading no.1548 image.
# loading no.1549 image.
# loading no.1550 image.
# loading no.1551 image.
# loading no.1552 image.
# loading no.1553 image.
# loading no.1554 image.
# loading no.1555 image.
# loading no.1556 image.
# loading no.1557 image.
# loading no.1558 image.
# loading no.1559 image.
# loading no.1560 image.
# loading no.1561 image.
# loading no.1562 image.
# loading no.1563 image.
# loading no.1564 image.
# loading no.1565 image.
# loading no.1566 image.
# loading no.1567 image.
# loading no.1568 image.
# loading no.1569 image.
# loading no.1570 image.
# loading no.1571 image.
# loading no.1572 image.
# loading no.1573 image.
# loading no.1574 image.
# loading no.1575 image.
# loading no.1576 image.
# loading no.1577 image.
# loading no.1578 image.
# loading no.1579 image.
# loading no.1580 image.
# loading no.1581 image.
# loading no.1582 image.
# loading no.1583 image.
# loading no.1584 image.
# loading no.1585 image.
# loading no.1586 image.
# loading no.1587 image.
# loading no.1588 image.
# loading no.1589 image.
# loading no.1590 image.
# loading no.1591 image.
# loading no.1592 image.
# loading no.1593 image.
# loading no.1594 image.
# loading no.1595 image.
# loading no.1596 image.
# loading no.1597 image.
# loading no.1598 image.
# loading no.1599 image.
# loading no.1600 image.
# loading no.1601 image.
# loading no.1602 image.
# loading no.1603 image.
# loading no.1604 image.
# loading no.1605 image.
# loading no.1606 image.
# loading no.1607 image.
# loading no.1608 image.
# loading no.1609 image.
# loading no.1610 image.
# loading no.1611 image.
# loading no.1612 image.
# loading no.1613 image.
# loading no.1614 image.
# loading no.1615 image.
# loading no.1616 image.
# loading no.1617 image.
# loading no.1618 image.
# loading no.1619 image.
# loading no.1620 image.
# loading no.1621 image.
# loading no.1622 image.
# loading no.1623 image.
# loading no.1624 image.
# loading no.1625 image.
# loading no.1626 image.
# loading no.1627 image.
# loading no.1628 image.
# loading no.1629 image.
# loading no.1630 image.
# loading no.1631 image.
# loading no.1632 image.
# loading no.1633 image.
# loading no.1634 image.
# loading no.1635 image.
# loading no.1636 image.
# loading no.1637 image.
# loading no.1638 image.
# loading no.1639 image.
# loading no.1640 image.
# loading no.1641 image.
# loading no.1642 image.
# loading no.1643 image.
# loading no.1644 image.
# loading no.1645 image.
# loading no.1646 image.
# loading no.1647 image.
# loading no.1648 image.
# loading no.1649 image.
# loading no.1650 image.
# loading no.1651 image.
# loading no.1652 image.
# loading no.1653 image.
# loading no.1654 image.
# loading no.1655 image.
# loading no.1656 image.
# loading no.1657 image.
# loading no.1658 image.
# loading no.1659 image.
# loading no.1660 image.
# loading no.1661 image.
# loading no.1662 image.
# loading no.1663 image.
# loading no.1664 image.
# loading no.1665 image.
# loading no.1666 image.
# loading no.1667 image.
# loading no.1668 image.
# loading no.1669 image.
# loading no.1670 image.
# loading no.1671 image.
# loading no.1672 image.
# loading no.1673 image.
# loading no.1674 image.
# loading no.1675 image.
# loading no.1676 image.
# loading no.1677 image.
# loading no.1678 image.
# loading no.1679 image.
# loading no.1680 image.
# loading no.1681 image.
# loading no.1682 image.
# loading no.1683 image.
# loading no.1684 image.
# loading no.1685 image.
# loading no.1686 image.
# loading no.1687 image.
# loading no.1688 image.
# loading no.1689 image.
# loading no.1690 image.
# loading no.1691 image.
# loading no.1692 image.
# loading no.1693 image.
# loading no.1694 image.
# loading no.1695 image.
# loading no.1696 image.
# loading no.1697 image.
# loading no.1698 image.
# loading no.1699 image.
# loading no.1700 image.
# loading no.1701 image.
# loading no.1702 image.
# loading no.1703 image.
# loading no.1704 image.
# loading no.1705 image.
# loading no.1706 image.
# loading no.1707 image.
# loading no.1708 image.
# loading no.1709 image.
# loading no.1710 image.
# loading no.1711 image.
# loading no.1712 image.
# loading no.1713 image.
# loading no.1714 image.
# loading no.1715 image.
# loading no.1716 image.
# loading no.1717 image.
# loading no.1718 image.
# loading no.1719 image.
# loading no.1720 image.
# loading no.1721 image.
# loading no.1722 image.
# loading no.1723 image.
# loading no.1724 image.
# loading no.1725 image.
# loading no.1726 image.
# loading no.1727 image.
# loading no.1728 image.
# loading no.1729 image.
# loading no.1730 image.
# loading no.1731 image.
# loading no.1732 image.
# loading no.1733 image.
# loading no.1734 image.
# loading no.1735 image.
# loading no.1736 image.
# loading no.1737 image.
# loading no.1738 image.
# loading no.1739 image.
# loading no.1740 image.
# loading no.1741 image.
# loading no.1742 image.
# loading no.1743 image.
# loading no.1744 image.
# loading no.1745 image.
# loading no.1746 image.
# loading no.1747 image.
# loading no.1748 image.
# loading no.1749 image.
# loading no.1750 image.
# loading no.1751 image.
# loading no.1752 image.
# loading no.1753 image.
# loading no.1754 image.
# loading no.1755 image.
# loading no.1756 image.
# loading no.1757 image.
# loading no.1758 image.
# loading no.1759 image.
# loading no.1760 image.
# loading no.1761 image.
# loading no.1762 image.
# loading no.1763 image.
# loading no.1764 image.
# loading no.1765 image.
# loading no.1766 image.
# loading no.1767 image.
# loading no.1768 image.
# loading no.1769 image.
# loading no.1770 image.
# loading no.1771 image.
# loading no.1772 image.
# loading no.1773 image.
# loading no.1774 image.
# loading no.1775 image.
# loading no.1776 image.
# loading no.1777 image.
# loading no.1778 image.
# loading no.1779 image.
# loading no.1780 image.
# loading no.1781 image.
# loading no.1782 image.
# loading no.1783 image.
# loading no.1784 image.
# loading no.1785 image.
# loading no.1786 image.
# loading no.1787 image.
# loading no.1788 image.
# loading no.1789 image.
# loading no.1790 image.
# loading no.1791 image.
# loading no.1792 image.
# loading no.1793 image.
# loading no.1794 image.
# loading no.1795 image.
# loading no.1796 image.
# loading no.1797 image.
# loading no.1798 image.
# loading no.1799 image.
# loading no.1800 image.
# loading no.1801 image.
# loading no.1802 image.
# loading no.1803 image.
# loading no.1804 image.
# loading no.1805 image.
# loading no.1806 image.
# loading no.1807 image.
# loading no.1808 image.
# loading no.1809 image.
# loading no.1810 image.
# loading no.1811 image.
# loading no.1812 image.
# loading no.1813 image.
# loading no.1814 image.
# loading no.1815 image.
# loading no.1816 image.
# loading no.1817 image.
# loading no.1818 image.
# loading no.1819 image.
# loading no.1820 image.
# loading no.1821 image.
# loading no.1822 image.
# loading no.1823 image.
# loading no.1824 image.
# loading no.1825 image.
# loading no.1826 image.
# loading no.1827 image.
# loading no.1828 image.
# loading no.1829 image.
# loading no.1830 image.
# loading no.1831 image.
# loading no.1832 image.
# loading no.1833 image.
# loading no.1834 image.
# loading no.1835 image.
# loading no.1836 image.
# loading no.1837 image.
# loading no.1838 image.
# loading no.1839 image.
# loading no.1840 image.
# loading no.1841 image.
# loading no.1842 image.
# loading no.1843 image.
# loading no.1844 image.
# loading no.1845 image.
# loading no.1846 image.
# loading no.1847 image.
# loading no.1848 image.
# loading no.1849 image.
# loading no.1850 image.
# loading no.1851 image.
# loading no.1852 image.
# loading no.1853 image.
# loading no.1854 image.
# loading no.1855 image.
# loading no.1856 image.
# loading no.1857 image.
# loading no.1858 image.
# loading no.1859 image.
# loading no.1860 image.
# loading no.1861 image.
# loading no.1862 image.
# loading no.1863 image.
# loading no.1864 image.
# loading no.1865 image.
# loading no.1866 image.
# loading no.1867 image.
# loading no.1868 image.
# loading no.1869 image.
# loading no.1870 image.
# loading no.1871 image.
# loading no.1872 image.
# loading no.1873 image.
# loading no.1874 image.
# loading no.1875 image.
# loading no.1876 image.
# loading no.1877 image.
# loading no.1878 image.
# loading no.1879 image.
# loading no.1880 image.
# loading no.1881 image.
# loading no.1882 image.
# loading no.1883 image.
# loading no.1884 image.
# loading no.1885 image.
# loading no.1886 image.
# loading no.1887 image.
# loading no.1888 image.
# loading no.1889 image.
# loading no.1890 image.
# loading no.1891 image.
# loading no.1892 image.
# loading no.1893 image.
# loading no.1894 image.
# loading no.1895 image.
# loading no.1896 image.
# loading no.1897 image.
# loading no.1898 image.
# loading no.1899 image.
# loading no.1900 image.
# loading no.1901 image.
# loading no.1902 image.
# loading no.1903 image.
# loading no.1904 image.
# loading no.1905 image.
# loading no.1906 image.
# loading no.1907 image.
# loading no.1908 image.
# loading no.1909 image.
# loading no.1910 image.
# loading no.1911 image.
# loading no.1912 image.
# loading no.1913 image.
# loading no.1914 image.
# loading no.1915 image.
# loading no.1916 image.
# loading no.1917 image.
# loading no.1918 image.
# loading no.1919 image.
# loading no.1920 image.
# loading no.1921 image.
# loading no.1922 image.
# loading no.1923 image.
# loading no.1924 image.
# loading no.1925 image.
# loading no.1926 image.
# loading no.1927 image.
# loading no.1928 image.
# loading no.1929 image.
# loading no.1930 image.
# loading no.1931 image.
# loading no.1932 image.
# loading no.1933 image.
# loading no.1934 image.
# loading no.1935 image.
# loading no.1936 image.
# loading no.1937 image.
# loading no.1938 image.
# loading no.1939 image.
# loading no.1940 image.
# loading no.1941 image.
# loading no.1942 image.
# loading no.1943 image.
# loading no.1944 image.
# loading no.1945 image.
# loading no.1946 image.
# loading no.1947 image.
# loading no.1948 image.
# loading no.1949 image.
# loading no.1950 image.
# loading no.1951 image.
# loading no.1952 image.
# loading no.1953 image.
# loading no.1954 image.
# loading no.1955 image.
# loading no.1956 image.
# loading no.1957 image.
# loading no.1958 image.
# loading no.1959 image.
# loading no.1960 image.
# loading no.1961 image.
# loading no.1962 image.
# loading no.1963 image.
# loading no.1964 image.
# loading no.1965 image.
# loading no.1966 image.
# loading no.1967 image.
# loading no.1968 image.
# loading no.1969 image.
# loading no.1970 image.
# loading no.1971 image.
# loading no.1972 image.
# loading no.1973 image.
# loading no.1974 image.
# loading no.1975 image.
# loading no.1976 image.
# loading no.1977 image.
# loading no.1978 image.
# loading no.1979 image.
# loading no.1980 image.
# loading no.1981 image.
# loading no.1982 image.
# loading no.1983 image.
# loading no.1984 image.
# loading no.1985 image.
# loading no.1986 image.
# loading no.1987 image.
# loading no.1988 image.
# loading no.1989 image.
# loading no.1990 image.
# loading no.1991 image.
# loading no.1992 image.
# loading no.1993 image.
# loading no.1994 image.
# loading no.1995 image.
# loading no.1996 image.
# loading no.1997 image.
# loading no.1998 image.
# loading no.1999 image.
# loading no.2000 image.
# loading no.2001 image.
# loading no.2002 image.
# loading no.2003 image.
# loading no.2004 image.
# loading no.2005 image.
# loading no.2006 image.
# loading no.2007 image.
# loading no.2008 image.
# loading no.2009 image.
# loading no.2010 image.
# loading no.2011 image.
# loading no.2012 image.
# loading no.2013 image.
# loading no.2014 image.
# loading no.2015 image.
# loading no.2016 image.
# loading no.2017 image.
# loading no.2018 image.
# loading no.2019 image.
# loading no.2020 image.
# loading no.2021 image.
# loading no.2022 image.
# loading no.2023 image.
# loading no.2024 image.
# loading no.2025 image.
# loading no.2026 image.
# loading no.2027 image.
# loading no.2028 image.
# loading no.2029 image.
# loading no.2030 image.
# loading no.2031 image.
# loading no.2032 image.
# loading no.2033 image.
# loading no.2034 image.
# loading no.2035 image.
# loading no.2036 image.
# loading no.2037 image.
# loading no.2038 image.
# loading no.2039 image.
# loading no.2040 image.
# loading no.2041 image.
# loading no.2042 image.
# loading no.2043 image.
# loading no.2044 image.
# loading no.2045 image.
# loading no.2046 image.
# loading no.2047 image.
# loading no.2048 image.
# loading no.2049 image.
# loading no.2050 image.
# loading no.2051 image.
# loading no.2052 image.
# loading no.2053 image.
# loading no.2054 image.
# loading no.2055 image.
# loading no.2056 image.
# loading no.2057 image.
# loading no.2058 image.
# loading no.2059 image.
# loading no.2060 image.
# loading no.2061 image.
# loading no.2062 image.
# loading no.2063 image.
# loading no.2064 image.
# loading no.2065 image.
# loading no.2066 image.
# loading no.2067 image.
# loading no.2068 image.
# loading no.2069 image.
# loading no.2070 image.
# loading no.2071 image.
# loading no.2072 image.
# loading no.2073 image.
# loading no.2074 image.
# loading no.2075 image.
# loading no.2076 image.
# loading no.2077 image.
# loading no.2078 image.
# loading no.2079 image.
# loading no.2080 image.
# loading no.2081 image.
# loading no.2082 image.
# loading no.2083 image.
# loading no.2084 image.
# loading no.2085 image.
# loading no.2086 image.
# loading no.2087 image.
# loading no.2088 image.
# loading no.2089 image.
# loading no.2090 image.
# loading no.2091 image.
# loading no.2092 image.
# loading no.2093 image.
# loading no.2094 image.
# loading no.2095 image.
# loading no.2096 image.
# loading no.2097 image.
# loading no.2098 image.
# loading no.2099 image.
# loading no.2100 image.
# loading no.2101 image.
# loading no.2102 image.
# loading no.2103 image.
# loading no.2104 image.
# loading no.2105 image.
# loading no.2106 image.
# loading no.2107 image.
# loading no.2108 image.
# loading no.2109 image.
# loading no.2110 image.
# loading no.2111 image.
# loading no.2112 image.
# loading no.2113 image.
# loading no.2114 image.
# loading no.2115 image.
# loading no.2116 image.
# loading no.2117 image.
# loading no.2118 image.
# loading no.2119 image.
# loading no.2120 image.
# loading no.2121 image.
# loading no.2122 image.
# loading no.2123 image.
# loading no.2124 image.
# loading no.2125 image.
# loading no.2126 image.
# loading no.2127 image.
# loading no.2128 image.
# loading no.2129 image.
# loading no.2130 image.
# loading no.2131 image.
# loading no.2132 image.
# loading no.2133 image.
# loading no.2134 image.
# ...
# loading no.13113 image.
# loading no.13114 image.
# loading no.13115 image.
# loading no.13116 image.
# loading no.13117 image.
# loading no.13118 image.
# loading no.13119 image.
# loading no.13120 image.
# loading no.13121 image.
# loading no.13122 image.
# loading no.13123 image.
# loading no.13124 image.
# loading no.13125 image.
# loading no.13126 image.
# loading no.13127 image.
# loading no.13128 image.
# loading no.13129 image.
# loading no.13130 image.
# loading no.13131 image.
# loading no.13132 image.
# loading no.13133 image.
# loading no.13134 image.
# loading no.13135 image.
# loading no.13136 image.
# loading no.13137 image.
# loading no.13138 image.
# loading no.13139 image.
# loading no.13140 image.
# loading no.13141 image.
# loading no.13142 image.
# loading no.13143 image.
# loading no.13144 image.
# loading no.13145 image.
# loading no.13146 image.
# loading no.13147 image.
# loading no.13148 image.
# loading no.13149 image.
# loading no.13150 image.
# loading no.13151 image.
# loading no.13152 image.
# loading no.13153 image.
# loading no.13154 image.
# loading no.13155 image.
# loading no.13156 image.
# loading no.13157 image.
# loading no.13158 image.
# loading no.13159 image.
# loading no.13160 image.
# loading no.13161 image.
# loading no.13162 image.
# loading no.13163 image.
# loading no.13164 image.
# loading no.13165 image.
# loading no.13166 image.
# loading no.13167 image.
# loading no.13168 image.
# loading no.13169 image.
# loading no.13170 image.
# loading no.13171 image.
# loading no.13172 image.
# loading no.13173 image.
# loading no.13174 image.
# loading no.13175 image.
# loading no.13176 image.
# loading no.13177 image.
# loading no.13178 image.
# loading no.13179 image.
# loading no.13180 image.
# loading no.13181 image.
# loading no.13182 image.
# loading no.13183 image.
# loading no.13184 image.
# loading no.13185 image.
# loading no.13186 image.
# loading no.13187 image.
# loading no.13188 image.
# loading no.13189 image.
# loading no.13190 image.
# loading no.13191 image.
# loading no.13192 image.
# loading no.13193 image.
# loading no.13194 image.
# loading no.13195 image.
# loading no.13196 image.
# loading no.13197 image.
# loading no.13198 image.
# loading no.13199 image.
# loading no.13200 image.
# loading no.13201 image.
# loading no.13202 image.
# loading no.13203 image.
# loading no.13204 image.
# loading no.13205 image.
# loading no.13206 image.
# loading no.13207 image.
# loading no.13208 image.
# loading no.13209 image.
# loading no.13210 image.
# loading no.13211 image.
# loading no.13212 image.
# loading no.13213 image.
# loading no.13214 image.
# loading no.13215 image.
# loading no.13216 image.
# loading no.13217 image.
# loading no.13218 image.
# loading no.13219 image.
# loading no.13220 image.
# loading no.13221 image.
# loading no.13222 image.
# loading no.13223 image.
# loading no.13224 image.
# loading no.13225 image.
# loading no.13226 image.
# loading no.13227 image.
# loading no.13228 image.
# loading no.13229 image.
# loading no.13230 image.
# loading no.13231 image.
# loading no.13232 image.
# loading no.13233 image.
# loading no.13234 image.
# loading no.13235 image.
# loading no.13236 image.
# loading no.13237 image.
# loading no.13238 image.
# loading no.13239 image.
# loading no.13240 image.
# loading no.13241 image.
# loading no.13242 image.
# loading no.13243 image.
# loading no.13244 image.
# loading no.13245 image.
# loading no.13246 image.
# loading no.13247 image.
# loading no.13248 image.
# loading no.13249 image.
# loading no.13250 image.
# loading no.13251 image.
# loading no.13252 image.
# loading no.13253 image.
# loading no.13254 image.
# loading no.13255 image.
# loading no.13256 image.
# loading no.13257 image.
# loading no.13258 image.
# loading no.13259 image.
# loading no.13260 image.
# loading no.13261 image.
# loading no.13262 image.
# loading no.13263 image.
# loading no.13264 image.
# loading no.13265 image.
# loading no.13266 image.
# loading no.13267 image.
# loading no.13268 image.
# loading no.13269 image.
# loading no.13270 image.
# loading no.13271 image.
# loading no.13272 image.
# loading no.13273 image.
# loading no.13274 image.
# loading no.13275 image.
# loading no.13276 image.
# loading no.13277 image.
# loading no.13278 image.
# loading no.13279 image.
# loading no.13280 image.
# loading no.13281 image.
# loading no.13282 image.
# loading no.13283 image.
# loading no.13284 image.
# loading no.13285 image.
# loading no.13286 image.
# loading no.13287 image.
# loading no.13288 image.
# loading no.13289 image.
# loading no.13290 image.
# loading no.13291 image.
# loading no.13292 image.
# loading no.13293 image.
# loading no.13294 image.
# loading no.13295 image.
# loading no.13296 image.
# loading no.13297 image.
# loading no.13298 image.
# loading no.13299 image.
# loading no.13300 image.
# loading no.13301 image.
# loading no.13302 image.
# loading no.13303 image.
# loading no.13304 image.
# loading no.13305 image.
# loading no.13306 image.
# loading no.13307 image.
# loading no.13308 image.
# loading no.13309 image.
# loading no.13310 image.
# loading no.13311 image.
# loading no.13312 image.
# loading no.13313 image.
# loading no.13314 image.
# loading no.13315 image.
# loading no.13316 image.
# loading no.13317 image.
# loading no.13318 image.
# loading no.13319 image.
# loading no.13320 image.
# loading no.13321 image.
# loading no.13322 image.
# loading no.13323 image.
# loading no.13324 image.
# loading no.13325 image.
# loading no.13326 image.
# loading no.13327 image.
# loading no.13328 image.
# loading no.13329 image.
# loading no.13330 image.
# loading no.13331 image.
# loading no.13332 image.
# loading no.13333 image.
# loading no.13334 image.
# loading no.13335 image.
# loading no.13336 image.
# loading no.13337 image.
# loading no.13338 image.
# loading no.13339 image.
# loading no.13340 image.
# loading no.13341 image.
# loading no.13342 image.
# loading no.13343 image.
# loading no.13344 image.
# loading no.13345 image.
# loading no.13346 image.
# loading no.13347 image.
# loading no.13348 image.
# loading no.13349 image.
# loading no.13350 image.
# loading no.13351 image.
# loading no.13352 image.
# loading no.13353 image.
# loading no.13354 image.
# loading no.13355 image.
# loading no.13356 image.
# loading no.13357 image.
# loading no.13358 image.
# loading no.13359 image.
# loading no.13360 image.
# loading no.13361 image.
# loading no.13362 image.
# loading no.13363 image.
# loading no.13364 image.
# loading no.13365 image.
# loading no.13366 image.
# loading no.13367 image.
# loading no.13368 image.
# loading no.13369 image.
# loading no.13370 image.
# loading no.13371 image.
# loading no.13372 image.
# loading no.13373 image.
# loading no.13374 image.
# loading no.13375 image.
# loading no.13376 image.
# loading no.13377 image.
# loading no.13378 image.
# loading no.13379 image.
# loading no.13380 image.
# loading no.13381 image.
# loading no.13382 image.
# loading no.13383 image.
# loading no.13384 image.
# loading no.13385 image.
# loading no.13386 image.
# loading no.13387 image.
# loading no.13388 image.
# loading no.13389 image.
# loading no.13390 image.
# loading no.13391 image.
# loading no.13392 image.
# loading no.13393 image.
# loading no.13394 image.
# loading no.13395 image.
# loading no.13396 image.
# loading no.13397 image.
# loading no.13398 image.
# loading no.13399 image.
# loading no.13400 image.
# loading no.13401 image.
# loading no.13402 image.
# loading no.13403 image.
# loading no.13404 image.
# loading no.13405 image.
# loading no.13406 image.
# loading no.13407 image.
# loading no.13408 image.
# loading no.13409 image.
# loading no.13410 image.
# loading no.13411 image.
# loading no.13412 image.
# loading no.13413 image.
# loading no.13414 image.
# loading no.13415 image.
# loading no.13416 image.
# loading no.13417 image.
# loading no.13418 image.
# loading no.13419 image.
# loading no.13420 image.
# loading no.13421 image.
# loading no.13422 image.
# loading no.13423 image.
# loading no.13424 image.
# loading no.13425 image.
# loading no.13426 image.
# loading no.13427 image.
# loading no.13428 image.
# loading no.13429 image.
# loading no.13430 image.
# loading no.13431 image.
# loading no.13432 image.
# loading no.13433 image.
# loading no.13434 image.
# loading no.13435 image.
# loading no.13436 image.
# loading no.13437 image.
# loading no.13438 image.
# loading no.13439 image.
# loading no.13440 image.
# loading no.13441 image.
# loading no.13442 image.
# loading no.13443 image.
# loading no.13444 image.
# loading no.13445 image.
# loading no.13446 image.
# loading no.13447 image.
# loading no.13448 image.
# loading no.13449 image.
# loading no.13450 image.
# loading no.13451 image.
# loading no.13452 image.
# loading no.13453 image.
# loading no.13454 image.
# loading no.13455 image.
# loading no.13456 image.
# loading no.13457 image.
# loading no.13458 image.
# loading no.13459 image.
# loading no.13460 image.
# loading no.13461 image.
# loading no.13462 image.
# loading no.13463 image.
# loading no.13464 image.
# loading no.13465 image.
# loading no.13466 image.
# loading no.13467 image.
# loading no.13468 image.
# loading no.13469 image.
# loading no.13470 image.
# loading no.13471 image.
# loading no.13472 image.
# loading no.13473 image.
# loading no.13474 image.
# loading no.13475 image.
# loading no.13476 image.
# loading no.13477 image.
# loading no.13478 image.
# loading no.13479 image.
# loading no.13480 image.
# loading no.13481 image.
# loading no.13482 image.
# loading no.13483 image.
# loading no.13484 image.
# loading no.13485 image.
# loading no.13486 image.
# loading no.13487 image.
# loading no.13488 image.
# loading no.13489 image.
# loading no.13490 image.
# loading no.13491 image.
# loading no.13492 image.
# loading no.13493 image.
# loading no.13494 image.
# loading no.13495 image.
# loading no.13496 image.
# loading no.13497 image.
# loading no.13498 image.
# loading no.13499 image.
# loading no.13500 image.
# loading no.13501 image.
# loading no.13502 image.
# loading no.13503 image.
# loading no.13504 image.
# loading no.13505 image.
# loading no.13506 image.
# loading no.13507 image.
# loading no.13508 image.
# loading no.13509 image.
# loading no.13510 image.
# loading no.13511 image.
# loading no.13512 image.
# loading no.13513 image.
# loading no.13514 image.
# loading no.13515 image.
# loading no.13516 image.
# loading no.13517 image.
# loading no.13518 image.
# loading no.13519 image.
# loading no.13520 image.
# loading no.13521 image.
# loading no.13522 image.
# loading no.13523 image.
# loading no.13524 image.
# loading no.13525 image.
# loading no.13526 image.
# loading no.13527 image.
# loading no.13528 image.
# loading no.13529 image.
# loading no.13530 image.
# loading no.13531 image.
# loading no.13532 image.
# loading no.13533 image.
# loading no.13534 image.
# loading no.13535 image.
# loading no.13536 image.
# loading no.13537 image.
# loading no.13538 image.
# loading no.13539 image.
# loading no.13540 image.
# loading no.13541 image.
# loading no.13542 image.
# loading no.13543 image.
# loading no.13544 image.
# loading no.13545 image.
# loading no.13546 image.
# loading no.13547 image.
# loading no.13548 image.
# loading no.13549 image.
# loading no.13550 image.
# loading no.13551 image.
# loading no.13552 image.
# loading no.13553 image.
# loading no.13554 image.
# loading no.13555 image.
# loading no.13556 image.
# loading no.13557 image.
# loading no.13558 image.
# loading no.13559 image.
# loading no.13560 image.
# loading no.13561 image.
# loading no.13562 image.
# loading no.13563 image.
# loading no.13564 image.
# loading no.13565 image.
# loading no.13566 image.
# loading no.13567 image.
# loading no.13568 image.
# loading no.13569 image.
# loading no.13570 image.
# loading no.13571 image.
# loading no.13572 image.
# loading no.13573 image.
# loading no.13574 image.
# loading no.13575 image.
# loading no.13576 image.
# loading no.13577 image.
# loading no.13578 image.
# loading no.13579 image.
# loading no.13580 image.
# loading no.13581 image.
# loading no.13582 image.
# loading no.13583 image.
# loading no.13584 image.
# loading no.13585 image.
# loading no.13586 image.
# loading no.13587 image.
# loading no.13588 image.
# loading no.13589 image.
# loading no.13590 image.
# loading no.13591 image.
# loading no.13592 image.
# loading no.13593 image.
# loading no.13594 image.
# loading no.13595 image.
# loading no.13596 image.
# loading no.13597 image.
# loading no.13598 image.
# loading no.13599 image.
# loading no.13600 image.
# loading no.13601 image.
# loading no.13602 image.
# loading no.13603 image.
# loading no.13604 image.
# loading no.13605 image.
# loading no.13606 image.
# loading no.13607 image.
# loading no.13608 image.
# loading no.13609 image.
# loading no.13610 image.
# loading no.13611 image.
# loading no.13612 image.
# loading no.13613 image.
# loading no.13614 image.
# loading no.13615 image.
# loading no.13616 image.
# loading no.13617 image.
# loading no.13618 image.
# loading no.13619 image.
# loading no.13620 image.
# loading no.13621 image.
# loading no.13622 image.
# loading no.13623 image.
# loading no.13624 image.
# loading no.13625 image.
# loading no.13626 image.
# loading no.13627 image.
# loading no.13628 image.
# loading no.13629 image.
# loading no.13630 image.
# loading no.13631 image.
# loading no.13632 image.
# loading no.13633 image.
# loading no.13634 image.
# loading no.13635 image.
# loading no.13636 image.
# loading no.13637 image.
# loading no.13638 image.
# loading no.13639 image.
# loading no.13640 image.
# loading no.13641 image.
# loading no.13642 image.
# loading no.13643 image.
# loading no.13644 image.
# loading no.13645 image.
# loading no.13646 image.
# loading no.13647 image.
# loading no.13648 image.
# loading no.13649 image.
# loading no.13650 image.
# loading no.13651 image.
# loading no.13652 image.
# loading no.13653 image.
# loading no.13654 image.
# loading no.13655 image.
# loading no.13656 image.
# loading no.13657 image.
# loading no.13658 image.
# loading no.13659 image.
# loading no.13660 image.
# loading no.13661 image.
# loading no.13662 image.
# loading no.13663 image.
# loading no.13664 image.
# loading no.13665 image.
# loading no.13666 image.
# loading no.13667 image.
# loading no.13668 image.
# loading no.13669 image.
# loading no.13670 image.
# loading no.13671 image.
# loading no.13672 image.
# loading no.13673 image.
# loading no.13674 image.
# loading no.13675 image.
# loading no.13676 image.
# loading no.13677 image.
# loading no.13678 image.
# loading no.13679 image.
# loading no.13680 image.
# loading no.13681 image.
# loading no.13682 image.
# loading no.13683 image.
# loading no.13684 image.
# loading no.13685 image.
# loading no.13686 image.
# loading no.13687 image.
# loading no.13688 image.
# loading no.13689 image.
# loading no.13690 image.
# loading no.13691 image.
# loading no.13692 image.
# loading no.13693 image.
# loading no.13694 image.
# loading no.13695 image.
# loading no.13696 image.
# loading no.13697 image.
# loading no.13698 image.
# loading no.13699 image.
# loading no.13700 image.
# loading no.13701 image.
# loading no.13702 image.
# loading no.13703 image.
# loading no.13704 image.
# loading no.13705 image.
# loading no.13706 image.
# loading no.13707 image.
# loading no.13708 image.
# loading no.13709 image.
# loading no.13710 image.
# loading no.13711 image.
# loading no.13712 image.
# loading no.13713 image.
# loading no.13714 image.
# loading no.13715 image.
# loading no.13716 image.
# loading no.13717 image.
# loading no.13718 image.
# loading no.13719 image.
# loading no.13720 image.
# loading no.13721 image.
# loading no.13722 image.
# loading no.13723 image.
# loading no.13724 image.
# loading no.13725 image.
# loading no.13726 image.
# loading no.13727 image.
# loading no.13728 image.
# loading no.13729 image.
# loading no.13730 image.
# loading no.13731 image.
# loading no.13732 image.
# loading no.13733 image.
# loading no.13734 image.
# loading no.13735 image.
# loading no.13736 image.
# loading no.13737 image.
# loading no.13738 image.
# loading no.13739 image.
# loading no.13740 image.
# loading no.13741 image.
# loading no.13742 image.
# loading no.13743 image.
# loading no.13744 image.
# loading no.13745 image.
# loading no.13746 image.
# loading no.13747 image.
# loading no.13748 image.
# loading no.13749 image.
# loading no.13750 image.
# loading no.13751 image.
# loading no.13752 image.
# loading no.13753 image.
# loading no.13754 image.
# loading no.13755 image.
# loading no.13756 image.
# loading no.13757 image.
# loading no.13758 image.
# loading no.13759 image.
# loading no.13760 image.
# loading no.13761 image.
# loading no.13762 image.
# loading no.13763 image.
# loading no.13764 image.
# loading no.13765 image.
# loading no.13766 image.
# loading no.13767 image.
# loading no.13768 image.
# loading no.13769 image.
# loading no.13770 image.
# loading no.13771 image.
# loading no.13772 image.
# loading no.13773 image.
# loading no.13774 image.
# loading no.13775 image.
# loading no.13776 image.
# loading no.13777 image.
# loading no.13778 image.

# %%
# ##The input shape
# 
# What flows between layers are tensors. Tensors can be seen as matrices, with shapes.   
# 
# In Keras, the input layer itself is not a layer, but a tensor. It's the starting tensor you send to the first hidden layer. This tensor must have the same shape as your training data. 
# 
# **Example:** if you have 30 images of 50x50 pixels in RGB (3 channels), the shape of your input data is `(30,50,50,3)`. Then your input layer tensor, must have this shape (see details in the "shapes in keras" section).   
# 
# Each type of layer requires the input with a certain number of dimensions:
# 
# - `Dense` layers require inputs as `(batch_size, input_size)`       
# - 2D convolutional layers need inputs as:`(batch_size, img_height, img_width, channels)`

# %%
x0.shape
# Out:
# (13779, 28, 28, 3)

# %%
y0=np.zeros(x0.shape[0])

# %%
y0.shape
# Out:
# (13779,)

# %%
file_path = '/Users/jeffreyscruggs/Desktop/A.I. Projects/cell_images/Parasitized/'
f_names = glob.glob(file_path + '*.png')

# %%
imgs = []
for i in range(len(f_names)):  #
    img = load_img(f_names[i], target_size=(28, 28, 3))  #
    arr_img = img_to_array(img)  # 图片转换为数组
    arr_img = np.expand_dims(arr_img, axis=0)   #
    imgs.append(arr_img) #
    print("loading no.%s image."%i)
# Out:
# loading no.0 image.
# loading no.1 image.
# loading no.2 image.
# loading no.3 image.
# loading no.4 image.
# loading no.5 image.
# loading no.6 image.
# loading no.7 image.
# loading no.8 image.
# loading no.9 image.
# loading no.10 image.
# loading no.11 image.
# loading no.12 image.
# loading no.13 image.
# loading no.14 image.
# loading no.15 image.
# loading no.16 image.
# loading no.17 image.
# loading no.18 image.
# loading no.19 image.
# loading no.20 image.
# loading no.21 image.
# loading no.22 image.
# loading no.23 image.
# loading no.24 image.
# loading no.25 image.
# loading no.26 image.
# loading no.27 image.
# loading no.28 image.
# loading no.29 image.
# loading no.30 image.
# loading no.31 image.
# loading no.32 image.
# loading no.33 image.
# loading no.34 image.
# loading no.35 image.
# loading no.36 image.
# loading no.37 image.
# loading no.38 image.
# loading no.39 image.
# loading no.40 image.
# loading no.41 image.
# loading no.42 image.
# loading no.43 image.
# loading no.44 image.
# loading no.45 image.
# loading no.46 image.
# loading no.47 image.
# loading no.48 image.
# loading no.49 image.
# loading no.50 image.
# loading no.51 image.
# loading no.52 image.
# loading no.53 image.
# loading no.54 image.
# loading no.55 image.
# loading no.56 image.
# loading no.57 image.
# loading no.58 image.
# loading no.59 image.
# loading no.60 image.
# loading no.61 image.
# loading no.62 image.
# loading no.63 image.
# loading no.64 image.
# loading no.65 image.
# loading no.66 image.
# loading no.67 image.
# loading no.68 image.
# loading no.69 image.
# loading no.70 image.
# loading no.71 image.
# loading no.72 image.
# loading no.73 image.
# loading no.74 image.
# loading no.75 image.
# loading no.76 image.
# loading no.77 image.
# loading no.78 image.
# loading no.79 image.
# loading no.80 image.
# loading no.81 image.
# loading no.82 image.
# loading no.83 image.
# loading no.84 image.
# loading no.85 image.
# loading no.86 image.
# loading no.87 image.
# loading no.88 image.
# loading no.89 image.
# loading no.90 image.
# loading no.91 image.
# loading no.92 image.
# loading no.93 image.
# loading no.94 image.
# loading no.95 image.
# loading no.96 image.
# loading no.97 image.
# loading no.98 image.
# loading no.99 image.
# loading no.100 image.
# loading no.101 image.
# loading no.102 image.
# loading no.103 image.
# loading no.104 image.
# loading no.105 image.
# loading no.106 image.
# loading no.107 image.
# loading no.108 image.
# loading no.109 image.
# loading no.110 image.
# loading no.111 image.
# loading no.112 image.
# loading no.113 image.
# loading no.114 image.
# loading no.115 image.
# loading no.116 image.
# loading no.117 image.
# loading no.118 image.
# loading no.119 image.
# loading no.120 image.
# loading no.121 image.
# loading no.122 image.
# loading no.123 image.
# loading no.124 image.
# loading no.125 image.
# loading no.126 image.
# loading no.127 image.
# loading no.128 image.
# loading no.129 image.
# loading no.130 image.
# loading no.131 image.
# loading no.132 image.
# loading no.133 image.
# loading no.134 image.
# loading no.135 image.
# loading no.136 image.
# loading no.137 image.
# loading no.138 image.
# loading no.139 image.
# loading no.140 image.
# loading no.141 image.
# loading no.142 image.
# loading no.143 image.
# loading no.144 image.
# loading no.145 image.
# loading no.146 image.
# loading no.147 image.
# loading no.148 image.
# loading no.149 image.
# loading no.150 image.
# loading no.151 image.
# loading no.152 image.
# loading no.153 image.
# loading no.154 image.
# loading no.155 image.
# loading no.156 image.
# loading no.157 image.
# loading no.158 image.
# loading no.159 image.
# loading no.160 image.
# loading no.161 image.
# loading no.162 image.
# loading no.163 image.
# loading no.164 image.
# loading no.165 image.
# loading no.166 image.
# loading no.167 image.
# loading no.168 image.
# loading no.169 image.
# loading no.170 image.
# loading no.171 image.
# loading no.172 image.
# loading no.173 image.
# loading no.174 image.
# loading no.175 image.
# loading no.176 image.
# loading no.177 image.
# loading no.178 image.
# loading no.179 image.
# loading no.180 image.
# loading no.181 image.
# loading no.182 image.
# loading no.183 image.
# loading no.184 image.
# loading no.185 image.
# loading no.186 image.
# loading no.187 image.
# loading no.188 image.
# loading no.189 image.
# loading no.190 image.
# loading no.191 image.
# loading no.192 image.
# loading no.193 image.
# loading no.194 image.
# loading no.195 image.
# loading no.196 image.
# loading no.197 image.
# loading no.198 image.
# loading no.199 image.
# loading no.200 image.
# loading no.201 image.
# loading no.202 image.
# loading no.203 image.
# loading no.204 image.
# loading no.205 image.
# loading no.206 image.
# loading no.207 image.
# loading no.208 image.
# loading no.209 image.
# loading no.210 image.
# loading no.211 image.
# loading no.212 image.
# loading no.213 image.
# loading no.214 image.
# loading no.215 image.
# loading no.216 image.
# loading no.217 image.
# loading no.218 image.
# loading no.219 image.
# loading no.220 image.
# loading no.221 image.
# loading no.222 image.
# loading no.223 image.
# loading no.224 image.
# loading no.225 image.
# loading no.226 image.
# loading no.227 image.
# loading no.228 image.
# loading no.229 image.
# loading no.230 image.
# loading no.231 image.
# loading no.232 image.
# loading no.233 image.
# loading no.234 image.
# loading no.235 image.
# loading no.236 image.
# loading no.237 image.
# loading no.238 image.
# loading no.239 image.
# loading no.240 image.
# loading no.241 image.
# loading no.242 image.
# loading no.243 image.
# loading no.244 image.
# loading no.245 image.
# loading no.246 image.
# loading no.247 image.
# loading no.248 image.
# loading no.249 image.
# loading no.250 image.
# loading no.251 image.
# loading no.252 image.
# loading no.253 image.
# loading no.254 image.
# loading no.255 image.
# loading no.256 image.
# loading no.257 image.
# loading no.258 image.
# loading no.259 image.
# loading no.260 image.
# loading no.261 image.
# loading no.262 image.
# loading no.263 image.
# loading no.264 image.
# loading no.265 image.
# loading no.266 image.
# loading no.267 image.
# loading no.268 image.
# loading no.269 image.
# loading no.270 image.
# loading no.271 image.
# loading no.272 image.
# loading no.273 image.
# loading no.274 image.
# loading no.275 image.
# loading no.276 image.
# loading no.277 image.
# loading no.278 image.
# loading no.279 image.
# loading no.280 image.
# loading no.281 image.
# loading no.282 image.
# loading no.283 image.
# loading no.284 image.
# loading no.285 image.
# loading no.286 image.
# loading no.287 image.
# loading no.288 image.
# loading no.289 image.
# loading no.290 image.
# loading no.291 image.
# loading no.292 image.
# loading no.293 image.
# loading no.294 image.
# loading no.295 image.
# loading no.296 image.
# loading no.297 image.
# loading no.298 image.
# loading no.299 image.
# loading no.300 image.
# loading no.301 image.
# loading no.302 image.
# loading no.303 image.
# loading no.304 image.
# loading no.305 image.
# loading no.306 image.
# loading no.307 image.
# loading no.308 image.
# loading no.309 image.
# loading no.310 image.
# loading no.311 image.
# loading no.312 image.
# loading no.313 image.
# loading no.314 image.
# loading no.315 image.
# loading no.316 image.
# loading no.317 image.
# loading no.318 image.
# loading no.319 image.
# loading no.320 image.
# loading no.321 image.
# loading no.322 image.
# loading no.323 image.
# loading no.324 image.
# loading no.325 image.
# loading no.326 image.
# loading no.327 image.
# loading no.328 image.
# loading no.329 image.
# loading no.330 image.
# loading no.331 image.
# loading no.332 image.
# loading no.333 image.
# loading no.334 image.
# loading no.335 image.
# loading no.336 image.
# loading no.337 image.
# loading no.338 image.
# loading no.339 image.
# loading no.340 image.
# loading no.341 image.
# loading no.342 image.
# loading no.343 image.
# loading no.344 image.
# loading no.345 image.
# loading no.346 image.
# loading no.347 image.
# loading no.348 image.
# loading no.349 image.
# loading no.350 image.
# loading no.351 image.
# loading no.352 image.
# loading no.353 image.
# loading no.354 image.
# loading no.355 image.
# loading no.356 image.
# loading no.357 image.
# loading no.358 image.
# loading no.359 image.
# loading no.360 image.
# loading no.361 image.
# loading no.362 image.
# loading no.363 image.
# loading no.364 image.
# loading no.365 image.
# loading no.366 image.
# loading no.367 image.
# loading no.368 image.
# loading no.369 image.
# loading no.370 image.
# loading no.371 image.
# loading no.372 image.
# loading no.373 image.
# loading no.374 image.
# loading no.375 image.
# loading no.376 image.
# loading no.377 image.
# loading no.378 image.
# loading no.379 image.
# loading no.380 image.
# loading no.381 image.
# loading no.382 image.
# loading no.383 image.
# loading no.384 image.
# loading no.385 image.
# loading no.386 image.
# loading no.387 image.
# loading no.388 image.
# loading no.389 image.
# loading no.390 image.
# loading no.391 image.
# loading no.392 image.
# loading no.393 image.
# loading no.394 image.
# loading no.395 image.
# loading no.396 image.
# loading no.397 image.
# loading no.398 image.
# loading no.399 image.
# loading no.400 image.
# loading no.401 image.
# loading no.402 image.
# loading no.403 image.
# loading no.404 image.
# loading no.405 image.
# loading no.406 image.
# loading no.407 image.
# loading no.408 image.
# loading no.409 image.
# loading no.410 image.
# loading no.411 image.
# loading no.412 image.
# loading no.413 image.
# loading no.414 image.
# loading no.415 image.
# loading no.416 image.
# loading no.417 image.
# loading no.418 image.
# loading no.419 image.
# loading no.420 image.
# loading no.421 image.
# loading no.422 image.
# loading no.423 image.
# loading no.424 image.
# loading no.425 image.
# loading no.426 image.
# loading no.427 image.
# loading no.428 image.
# loading no.429 image.
# loading no.430 image.
# loading no.431 image.
# loading no.432 image.
# loading no.433 image.
# loading no.434 image.
# loading no.435 image.
# loading no.436 image.
# loading no.437 image.
# loading no.438 image.
# loading no.439 image.
# loading no.440 image.
# loading no.441 image.
# loading no.442 image.
# loading no.443 image.
# loading no.444 image.
# loading no.445 image.
# loading no.446 image.
# loading no.447 image.
# loading no.448 image.
# loading no.449 image.
# loading no.450 image.
# loading no.451 image.
# loading no.452 image.
# loading no.453 image.
# loading no.454 image.
# loading no.455 image.
# loading no.456 image.
# loading no.457 image.
# loading no.458 image.
# loading no.459 image.
# loading no.460 image.
# loading no.461 image.
# loading no.462 image.
# loading no.463 image.
# loading no.464 image.
# loading no.465 image.
# loading no.466 image.
# loading no.467 image.
# loading no.468 image.
# loading no.469 image.
# loading no.470 image.
# loading no.471 image.
# loading no.472 image.
# loading no.473 image.
# loading no.474 image.
# loading no.475 image.
# loading no.476 image.
# loading no.477 image.
# loading no.478 image.
# loading no.479 image.
# loading no.480 image.
# loading no.481 image.
# loading no.482 image.
# loading no.483 image.
# loading no.484 image.
# loading no.485 image.
# loading no.486 image.
# loading no.487 image.
# loading no.488 image.
# loading no.489 image.
# loading no.490 image.
# loading no.491 image.
# loading no.492 image.
# loading no.493 image.
# loading no.494 image.
# loading no.495 image.
# loading no.496 image.
# loading no.497 image.
# loading no.498 image.
# loading no.499 image.
# loading no.500 image.
# loading no.501 image.
# loading no.502 image.
# loading no.503 image.
# loading no.504 image.
# loading no.505 image.
# loading no.506 image.
# loading no.507 image.
# loading no.508 image.
# loading no.509 image.
# loading no.510 image.
# loading no.511 image.
# loading no.512 image.
# loading no.513 image.
# loading no.514 image.
# loading no.515 image.
# loading no.516 image.
# loading no.517 image.
# loading no.518 image.
# loading no.519 image.
# loading no.520 image.
# loading no.521 image.
# loading no.522 image.
# loading no.523 image.
# loading no.524 image.
# loading no.525 image.
# loading no.526 image.
# loading no.527 image.
# loading no.528 image.
# loading no.529 image.
# loading no.530 image.
# loading no.531 image.
# loading no.532 image.
# loading no.533 image.
# loading no.534 image.
# loading no.535 image.
# loading no.536 image.
# loading no.537 image.
# loading no.538 image.
# loading no.539 image.
# loading no.540 image.
# loading no.541 image.
# loading no.542 image.
# loading no.543 image.
# loading no.544 image.
# loading no.545 image.
# loading no.546 image.
# loading no.547 image.
# loading no.548 image.
# loading no.549 image.
# loading no.550 image.
# loading no.551 image.
# loading no.552 image.
# loading no.553 image.
# loading no.554 image.
# loading no.555 image.
# loading no.556 image.
# loading no.557 image.
# loading no.558 image.
# loading no.559 image.
# loading no.560 image.
# loading no.561 image.
# loading no.562 image.
# loading no.563 image.
# loading no.564 image.
# loading no.565 image.
# loading no.566 image.
# loading no.567 image.
# loading no.568 image.
# loading no.569 image.
# loading no.570 image.
# loading no.571 image.
# loading no.572 image.
# loading no.573 image.
# loading no.574 image.
# loading no.575 image.
# loading no.576 image.
# loading no.577 image.
# loading no.578 image.
# loading no.579 image.
# loading no.580 image.
# loading no.581 image.
# loading no.582 image.
# loading no.583 image.
# loading no.584 image.
# loading no.585 image.
# loading no.586 image.
# loading no.587 image.
# loading no.588 image.
# loading no.589 image.
# loading no.590 image.
# loading no.591 image.
# loading no.592 image.
# loading no.593 image.
# loading no.594 image.
# loading no.595 image.
# loading no.596 image.
# loading no.597 image.
# loading no.598 image.
# loading no.599 image.
# loading no.600 image.
# loading no.601 image.
# loading no.602 image.
# loading no.603 image.
# loading no.604 image.
# loading no.605 image.
# loading no.606 image.
# loading no.607 image.
# loading no.608 image.
# loading no.609 image.
# loading no.610 image.
# loading no.611 image.
# loading no.612 image.
# loading no.613 image.
# loading no.614 image.
# loading no.615 image.
# loading no.616 image.
# loading no.617 image.
# loading no.618 image.
# loading no.619 image.
# loading no.620 image.
# loading no.621 image.
# loading no.622 image.
# loading no.623 image.
# loading no.624 image.
# loading no.625 image.
# loading no.626 image.
# loading no.627 image.
# loading no.628 image.
# loading no.629 image.
# loading no.630 image.
# loading no.631 image.
# loading no.632 image.
# loading no.633 image.
# loading no.634 image.
# loading no.635 image.
# loading no.636 image.
# loading no.637 image.
# loading no.638 image.
# loading no.639 image.
# loading no.640 image.
# loading no.641 image.
# loading no.642 image.
# loading no.643 image.
# loading no.644 image.
# loading no.645 image.
# loading no.646 image.
# loading no.647 image.
# loading no.648 image.
# loading no.649 image.
# loading no.650 image.
# loading no.651 image.
# loading no.652 image.
# loading no.653 image.
# loading no.654 image.
# loading no.655 image.
# loading no.656 image.
# loading no.657 image.
# loading no.658 image.
# loading no.659 image.
# loading no.660 image.
# loading no.661 image.
# loading no.662 image.
# loading no.663 image.
# loading no.664 image.
# loading no.665 image.
# loading no.666 image.
# loading no.667 image.
# loading no.668 image.
# loading no.669 image.
# loading no.670 image.
# loading no.671 image.
# loading no.672 image.
# loading no.673 image.
# loading no.674 image.
# loading no.675 image.
# loading no.676 image.
# loading no.677 image.
# loading no.678 image.
# loading no.679 image.
# loading no.680 image.
# loading no.681 image.
# loading no.682 image.
# loading no.683 image.
# loading no.684 image.
# loading no.685 image.
# loading no.686 image.
# loading no.687 image.
# loading no.688 image.
# loading no.689 image.
# loading no.690 image.
# loading no.691 image.
# loading no.692 image.
# loading no.693 image.
# loading no.694 image.
# loading no.695 image.
# loading no.696 image.
# loading no.697 image.
# loading no.698 image.
# loading no.699 image.
# loading no.700 image.
# loading no.701 image.
# loading no.702 image.
# loading no.703 image.
# loading no.704 image.
# loading no.705 image.
# loading no.706 image.
# loading no.707 image.
# loading no.708 image.
# loading no.709 image.
# loading no.710 image.
# loading no.711 image.
# loading no.712 image.
# loading no.713 image.
# loading no.714 image.
# loading no.715 image.
# loading no.716 image.
# loading no.717 image.
# loading no.718 image.
# loading no.719 image.
# loading no.720 image.
# loading no.721 image.
# loading no.722 image.
# loading no.723 image.
# loading no.724 image.
# loading no.725 image.
# loading no.726 image.
# loading no.727 image.
# loading no.728 image.
# loading no.729 image.
# loading no.730 image.
# loading no.731 image.
# loading no.732 image.
# loading no.733 image.
# loading no.734 image.
# loading no.735 image.
# loading no.736 image.
# loading no.737 image.
# loading no.738 image.
# loading no.739 image.
# loading no.740 image.
# loading no.741 image.
# loading no.742 image.
# loading no.743 image.
# loading no.744 image.
# loading no.745 image.
# loading no.746 image.
# loading no.747 image.
# loading no.748 image.
# loading no.749 image.
# loading no.750 image.
# loading no.751 image.
# loading no.752 image.
# loading no.753 image.
# loading no.754 image.
# loading no.755 image.
# loading no.756 image.
# loading no.757 image.
# loading no.758 image.
# loading no.759 image.
# loading no.760 image.
# loading no.761 image.
# loading no.762 image.
# loading no.763 image.
# loading no.764 image.
# loading no.765 image.
# loading no.766 image.
# loading no.767 image.
# loading no.768 image.
# loading no.769 image.
# loading no.770 image.
# loading no.771 image.
# loading no.772 image.
# loading no.773 image.
# loading no.774 image.
# loading no.775 image.
# loading no.776 image.
# loading no.777 image.
# loading no.778 image.
# loading no.779 image.
# loading no.780 image.
# loading no.781 image.
# loading no.782 image.
# loading no.783 image.
# loading no.784 image.
# loading no.785 image.
# loading no.786 image.
# loading no.787 image.
# loading no.788 image.
# loading no.789 image.
# loading no.790 image.
# loading no.791 image.
# loading no.792 image.
# loading no.793 image.
# loading no.794 image.
# loading no.795 image.
# loading no.796 image.
# loading no.797 image.
# loading no.798 image.
# loading no.799 image.
# loading no.800 image.
# loading no.801 image.
# loading no.802 image.
# loading no.803 image.
# loading no.804 image.
# loading no.805 image.
# loading no.806 image.
# loading no.807 image.
# loading no.808 image.
# loading no.809 image.
# loading no.810 image.
# loading no.811 image.
# loading no.812 image.
# loading no.813 image.
# loading no.814 image.
# loading no.815 image.
# loading no.816 image.
# loading no.817 image.
# loading no.818 image.
# loading no.819 image.
# loading no.820 image.
# loading no.821 image.
# loading no.822 image.
# loading no.823 image.
# loading no.824 image.
# loading no.825 image.
# loading no.826 image.
# loading no.827 image.
# loading no.828 image.
# loading no.829 image.
# loading no.830 image.
# loading no.831 image.
# loading no.832 image.
# loading no.833 image.
# loading no.834 image.
# loading no.835 image.
# loading no.836 image.
# loading no.837 image.
# loading no.838 image.
# loading no.839 image.
# loading no.840 image.
# loading no.841 image.
# loading no.842 image.
# loading no.843 image.
# loading no.844 image.
# loading no.845 image.
# loading no.846 image.
# loading no.847 image.
# loading no.848 image.
# loading no.849 image.
# loading no.850 image.
# loading no.851 image.
# loading no.852 image.
# loading no.853 image.
# loading no.854 image.
# loading no.855 image.
# loading no.856 image.
# loading no.857 image.
# loading no.858 image.
# loading no.859 image.
# loading no.860 image.
# loading no.861 image.
# loading no.862 image.
# loading no.863 image.
# loading no.864 image.
# loading no.865 image.
# loading no.866 image.
# loading no.867 image.
# loading no.868 image.
# loading no.869 image.
# loading no.870 image.
# loading no.871 image.
# loading no.872 image.
# loading no.873 image.
# loading no.874 image.
# loading no.875 image.
# loading no.876 image.
# loading no.877 image.
# loading no.878 image.
# loading no.879 image.
# loading no.880 image.
# loading no.881 image.
# loading no.882 image.
# loading no.883 image.
# loading no.884 image.
# loading no.885 image.
# loading no.886 image.
# loading no.887 image.
# loading no.888 image.
# loading no.889 image.
# loading no.890 image.
# loading no.891 image.
# loading no.892 image.
# loading no.893 image.
# loading no.894 image.
# loading no.895 image.
# loading no.896 image.
# loading no.897 image.
# loading no.898 image.
# loading no.899 image.
# loading no.900 image.
# loading no.901 image.
# loading no.902 image.
# loading no.903 image.
# loading no.904 image.
# loading no.905 image.
# loading no.906 image.
# loading no.907 image.
# loading no.908 image.
# loading no.909 image.
# loading no.910 image.
# loading no.911 image.
# loading no.912 image.
# loading no.913 image.
# loading no.914 image.
# loading no.915 image.
# loading no.916 image.
# loading no.917 image.
# loading no.918 image.
# loading no.919 image.
# loading no.920 image.
# loading no.921 image.
# loading no.922 image.
# loading no.923 image.
# loading no.924 image.
# loading no.925 image.
# loading no.926 image.
# loading no.927 image.
# loading no.928 image.
# loading no.929 image.
# loading no.930 image.
# loading no.931 image.
# loading no.932 image.
# loading no.933 image.
# loading no.934 image.
# loading no.935 image.
# loading no.936 image.
# loading no.937 image.
# loading no.938 image.
# loading no.939 image.
# loading no.940 image.
# loading no.941 image.
# loading no.942 image.
# loading no.943 image.
# loading no.944 image.
# loading no.945 image.
# loading no.946 image.
# loading no.947 image.
# loading no.948 image.
# loading no.949 image.
# loading no.950 image.
# loading no.951 image.
# loading no.952 image.
# loading no.953 image.
# loading no.954 image.
# loading no.955 image.
# loading no.956 image.
# loading no.957 image.
# loading no.958 image.
# loading no.959 image.
# loading no.960 image.
# loading no.961 image.
# loading no.962 image.
# loading no.963 image.
# loading no.964 image.
# loading no.965 image.
# loading no.966 image.
# loading no.967 image.
# loading no.968 image.
# loading no.969 image.
# loading no.970 image.
# loading no.971 image.
# loading no.972 image.
# loading no.973 image.
# loading no.974 image.
# loading no.975 image.
# loading no.976 image.
# loading no.977 image.
# loading no.978 image.
# loading no.979 image.
# loading no.980 image.
# loading no.981 image.
# loading no.982 image.
# loading no.983 image.
# loading no.984 image.
# loading no.985 image.
# loading no.986 image.
# loading no.987 image.
# loading no.988 image.
# loading no.989 image.
# loading no.990 image.
# loading no.991 image.
# loading no.992 image.
# loading no.993 image.
# loading no.994 image.
# loading no.995 image.
# loading no.996 image.
# loading no.997 image.
# loading no.998 image.
# loading no.999 image.
# loading no.1000 image.
# loading no.1001 image.
# loading no.1002 image.
# loading no.1003 image.
# loading no.1004 image.
# loading no.1005 image.
# loading no.1006 image.
# loading no.1007 image.
# loading no.1008 image.
# loading no.1009 image.
# loading no.1010 image.
# loading no.1011 image.
# loading no.1012 image.
# loading no.1013 image.
# loading no.1014 image.
# loading no.1015 image.
# loading no.1016 image.
# loading no.1017 image.
# loading no.1018 image.
# loading no.1019 image.
# loading no.1020 image.
# loading no.1021 image.
# loading no.1022 image.
# loading no.1023 image.
# loading no.1024 image.
# loading no.1025 image.
# loading no.1026 image.
# loading no.1027 image.
# loading no.1028 image.
# loading no.1029 image.
# loading no.1030 image.
# loading no.1031 image.
# loading no.1032 image.
# loading no.1033 image.
# loading no.1034 image.
# loading no.1035 image.
# loading no.1036 image.
# loading no.1037 image.
# loading no.1038 image.
# loading no.1039 image.
# loading no.1040 image.
# loading no.1041 image.
# loading no.1042 image.
# loading no.1043 image.
# loading no.1044 image.
# loading no.1045 image.
# loading no.1046 image.
# loading no.1047 image.
# loading no.1048 image.
# loading no.1049 image.
# loading no.1050 image.
# loading no.1051 image.
# loading no.1052 image.
# loading no.1053 image.
# loading no.1054 image.
# loading no.1055 image.
# loading no.1056 image.
# loading no.1057 image.
# loading no.1058 image.
# loading no.1059 image.
# loading no.1060 image.
# loading no.1061 image.
# loading no.1062 image.
# loading no.1063 image.
# loading no.1064 image.
# loading no.1065 image.
# loading no.1066 image.
# loading no.1067 image.
# loading no.1068 image.
# loading no.1069 image.
# loading no.1070 image.
# loading no.1071 image.
# loading no.1072 image.
# loading no.1073 image.
# loading no.1074 image.
# loading no.1075 image.
# loading no.1076 image.
# loading no.1077 image.
# loading no.1078 image.
# loading no.1079 image.
# loading no.1080 image.
# loading no.1081 image.
# loading no.1082 image.
# loading no.1083 image.
# loading no.1084 image.
# loading no.1085 image.
# loading no.1086 image.
# loading no.1087 image.
# loading no.1088 image.
# loading no.1089 image.
# loading no.1090 image.
# loading no.1091 image.
# loading no.1092 image.
# loading no.1093 image.
# loading no.1094 image.
# loading no.1095 image.
# loading no.1096 image.
# loading no.1097 image.
# loading no.1098 image.
# loading no.1099 image.
# loading no.1100 image.
# loading no.1101 image.
# loading no.1102 image.
# loading no.1103 image.
# loading no.1104 image.
# loading no.1105 image.
# loading no.1106 image.
# loading no.1107 image.
# loading no.1108 image.
# loading no.1109 image.
# loading no.1110 image.
# loading no.1111 image.
# loading no.1112 image.
# loading no.1113 image.
# loading no.1114 image.
# loading no.1115 image.
# loading no.1116 image.
# loading no.1117 image.
# loading no.1118 image.
# loading no.1119 image.
# loading no.1120 image.
# loading no.1121 image.
# loading no.1122 image.
# loading no.1123 image.
# loading no.1124 image.
# loading no.1125 image.
# loading no.1126 image.
# loading no.1127 image.
# loading no.1128 image.
# loading no.1129 image.
# loading no.1130 image.
# loading no.1131 image.
# loading no.1132 image.
# loading no.1133 image.
# loading no.1134 image.
# loading no.1135 image.
# loading no.1136 image.
# loading no.1137 image.
# loading no.1138 image.
# loading no.1139 image.
# loading no.1140 image.
# loading no.1141 image.
# loading no.1142 image.
# loading no.1143 image.
# loading no.1144 image.
# loading no.1145 image.
# loading no.1146 image.
# loading no.1147 image.
# loading no.1148 image.
# loading no.1149 image.
# loading no.1150 image.
# loading no.1151 image.
# loading no.1152 image.
# loading no.1153 image.
# loading no.1154 image.
# loading no.1155 image.
# loading no.1156 image.
# loading no.1157 image.
# loading no.1158 image.
# loading no.1159 image.
# loading no.1160 image.
# loading no.1161 image.
# loading no.1162 image.
# loading no.1163 image.
# loading no.1164 image.
# loading no.1165 image.
# loading no.1166 image.
# loading no.1167 image.
# loading no.1168 image.
# loading no.1169 image.
# loading no.1170 image.
# loading no.1171 image.
# loading no.1172 image.
# loading no.1173 image.
# loading no.1174 image.
# loading no.1175 image.
# loading no.1176 image.
# loading no.1177 image.
# loading no.1178 image.
# loading no.1179 image.
# loading no.1180 image.
# loading no.1181 image.
# loading no.1182 image.
# loading no.1183 image.
# loading no.1184 image.
# loading no.1185 image.
# loading no.1186 image.
# loading no.1187 image.
# loading no.1188 image.
# loading no.1189 image.
# loading no.1190 image.
# loading no.1191 image.
# loading no.1192 image.
# loading no.1193 image.
# loading no.1194 image.
# loading no.1195 image.
# loading no.1196 image.
# loading no.1197 image.
# loading no.1198 image.
# loading no.1199 image.
# loading no.1200 image.
# loading no.1201 image.
# loading no.1202 image.
# loading no.1203 image.
# loading no.1204 image.
# loading no.1205 image.
# loading no.1206 image.
# loading no.1207 image.
# loading no.1208 image.
# loading no.1209 image.
# loading no.1210 image.
# loading no.1211 image.
# loading no.1212 image.
# loading no.1213 image.
# loading no.1214 image.
# loading no.1215 image.
# loading no.1216 image.
# loading no.1217 image.
# loading no.1218 image.
# loading no.1219 image.
# loading no.1220 image.
# loading no.1221 image.
# loading no.1222 image.
# loading no.1223 image.
# loading no.1224 image.
# loading no.1225 image.
# loading no.1226 image.
# loading no.1227 image.
# loading no.1228 image.
# loading no.1229 image.
# loading no.1230 image.
# loading no.1231 image.
# loading no.1232 image.
# loading no.1233 image.
# loading no.1234 image.
# loading no.1235 image.
# loading no.1236 image.
# loading no.1237 image.
# loading no.1238 image.
# loading no.1239 image.
# loading no.1240 image.
# loading no.1241 image.
# loading no.1242 image.
# loading no.1243 image.
# loading no.1244 image.
# loading no.1245 image.
# loading no.1246 image.
# loading no.1247 image.
# loading no.1248 image.
# loading no.1249 image.
# loading no.1250 image.
# loading no.1251 image.
# loading no.1252 image.
# loading no.1253 image.
# loading no.1254 image.
# loading no.1255 image.
# loading no.1256 image.
# loading no.1257 image.
# loading no.1258 image.
# loading no.1259 image.
# loading no.1260 image.
# loading no.1261 image.
# loading no.1262 image.
# loading no.1263 image.
# loading no.1264 image.
# loading no.1265 image.
# loading no.1266 image.
# loading no.1267 image.
# loading no.1268 image.
# loading no.1269 image.
# loading no.1270 image.
# loading no.1271 image.
# loading no.1272 image.
# loading no.1273 image.
# loading no.1274 image.
# loading no.1275 image.
# loading no.1276 image.
# loading no.1277 image.
# loading no.1278 image.
# loading no.1279 image.
# loading no.1280 image.
# loading no.1281 image.
# loading no.1282 image.
# loading no.1283 image.
# loading no.1284 image.
# loading no.1285 image.
# loading no.1286 image.
# loading no.1287 image.
# loading no.1288 image.
# loading no.1289 image.
# loading no.1290 image.
# loading no.1291 image.
# loading no.1292 image.
# loading no.1293 image.
# loading no.1294 image.
# loading no.1295 image.
# loading no.1296 image.
# loading no.1297 image.
# loading no.1298 image.
# loading no.1299 image.
# loading no.1300 image.
# loading no.1301 image.
# loading no.1302 image.
# loading no.1303 image.
# loading no.1304 image.
# loading no.1305 image.
# loading no.1306 image.
# loading no.1307 image.
# loading no.1308 image.
# loading no.1309 image.
# loading no.1310 image.
# loading no.1311 image.
# loading no.1312 image.
# loading no.1313 image.
# loading no.1314 image.
# loading no.1315 image.
# loading no.1316 image.
# loading no.1317 image.
# loading no.1318 image.
# loading no.1319 image.
# loading no.1320 image.
# loading no.1321 image.
# loading no.1322 image.
# loading no.1323 image.
# loading no.1324 image.
# loading no.1325 image.
# loading no.1326 image.
# loading no.1327 image.
# loading no.1328 image.
# loading no.1329 image.
# loading no.1330 image.
# loading no.1331 image.
# loading no.1332 image.
# loading no.1333 image.
# loading no.1334 image.
# loading no.1335 image.
# loading no.1336 image.
# loading no.1337 image.
# loading no.1338 image.
# loading no.1339 image.
# loading no.1340 image.
# loading no.1341 image.
# loading no.1342 image.
# loading no.1343 image.
# loading no.1344 image.
# loading no.1345 image.
# loading no.1346 image.
# loading no.1347 image.
# loading no.1348 image.
# loading no.1349 image.
# loading no.1350 image.
# loading no.1351 image.
# loading no.1352 image.
# loading no.1353 image.
# loading no.1354 image.
# loading no.1355 image.
# loading no.1356 image.
# loading no.1357 image.
# loading no.1358 image.
# loading no.1359 image.
# loading no.1360 image.
# loading no.1361 image.
# loading no.1362 image.
# loading no.1363 image.
# loading no.1364 image.
# loading no.1365 image.
# loading no.1366 image.
# loading no.1367 image.
# loading no.1368 image.
# loading no.1369 image.
# loading no.1370 image.
# loading no.1371 image.
# loading no.1372 image.
# loading no.1373 image.
# loading no.1374 image.
# loading no.1375 image.
# loading no.1376 image.
# loading no.1377 image.
# loading no.1378 image.
# loading no.1379 image.
# loading no.1380 image.
# loading no.1381 image.
# loading no.1382 image.
# loading no.1383 image.
# loading no.1384 image.
# loading no.1385 image.
# loading no.1386 image.
# loading no.1387 image.
# loading no.1388 image.
# loading no.1389 image.
# loading no.1390 image.
# loading no.1391 image.
# loading no.1392 image.
# loading no.1393 image.
# loading no.1394 image.
# loading no.1395 image.
# loading no.1396 image.
# loading no.1397 image.
# loading no.1398 image.
# loading no.1399 image.
# loading no.1400 image.
# loading no.1401 image.
# loading no.1402 image.
# loading no.1403 image.
# loading no.1404 image.
# loading no.1405 image.
# loading no.1406 image.
# loading no.1407 image.
# loading no.1408 image.
# loading no.1409 image.
# loading no.1410 image.
# loading no.1411 image.
# loading no.1412 image.
# loading no.1413 image.
# loading no.1414 image.
# loading no.1415 image.
# loading no.1416 image.
# loading no.1417 image.
# loading no.1418 image.
# loading no.1419 image.
# loading no.1420 image.
# loading no.1421 image.
# loading no.1422 image.
# loading no.1423 image.
# loading no.1424 image.
# loading no.1425 image.
# loading no.1426 image.
# loading no.1427 image.
# loading no.1428 image.
# loading no.1429 image.
# loading no.1430 image.
# loading no.1431 image.
# loading no.1432 image.
# loading no.1433 image.
# loading no.1434 image.
# loading no.1435 image.
# loading no.1436 image.
# loading no.1437 image.
# loading no.1438 image.
# loading no.1439 image.
# loading no.1440 image.
# loading no.1441 image.
# loading no.1442 image.
# loading no.1443 image.
# loading no.1444 image.
# loading no.1445 image.
# loading no.1446 image.
# loading no.1447 image.
# loading no.1448 image.
# loading no.1449 image.
# loading no.1450 image.
# loading no.1451 image.
# loading no.1452 image.
# loading no.1453 image.
# loading no.1454 image.
# loading no.1455 image.
# loading no.1456 image.
# loading no.1457 image.
# loading no.1458 image.
# loading no.1459 image.
# loading no.1460 image.
# loading no.1461 image.
# loading no.1462 image.
# loading no.1463 image.
# loading no.1464 image.
# loading no.1465 image.
# loading no.1466 image.
# loading no.1467 image.
# loading no.1468 image.
# loading no.1469 image.
# loading no.1470 image.
# loading no.1471 image.
# loading no.1472 image.
# loading no.1473 image.
# loading no.1474 image.
# loading no.1475 image.
# loading no.1476 image.
# loading no.1477 image.
# loading no.1478 image.
# loading no.1479 image.
# loading no.1480 image.
# loading no.1481 image.
# loading no.1482 image.
# loading no.1483 image.
# loading no.1484 image.
# loading no.1485 image.
# loading no.1486 image.
# loading no.1487 image.
# loading no.1488 image.
# loading no.1489 image.
# loading no.1490 image.
# loading no.1491 image.
# loading no.1492 image.
# loading no.1493 image.
# loading no.1494 image.
# loading no.1495 image.
# loading no.1496 image.
# loading no.1497 image.
# loading no.1498 image.
# loading no.1499 image.
# loading no.1500 image.
# loading no.1501 image.
# loading no.1502 image.
# loading no.1503 image.
# loading no.1504 image.
# loading no.1505 image.
# loading no.1506 image.
# loading no.1507 image.
# loading no.1508 image.
# loading no.1509 image.
# loading no.1510 image.
# loading no.1511 image.
# loading no.1512 image.
# loading no.1513 image.
# loading no.1514 image.
# loading no.1515 image.
# loading no.1516 image.
# loading no.1517 image.
# loading no.1518 image.
# loading no.1519 image.
# loading no.1520 image.
# loading no.1521 image.
# loading no.1522 image.
# loading no.1523 image.
# loading no.1524 image.
# loading no.1525 image.
# loading no.1526 image.
# loading no.1527 image.
# loading no.1528 image.
# loading no.1529 image.
# loading no.1530 image.
# loading no.1531 image.
# loading no.1532 image.
# loading no.1533 image.
# loading no.1534 image.
# loading no.1535 image.
# loading no.1536 image.
# loading no.1537 image.
# loading no.1538 image.
# loading no.1539 image.
# loading no.1540 image.
# loading no.1541 image.
# loading no.1542 image.
# loading no.1543 image.
# loading no.1544 image.
# loading no.1545 image.
# loading no.1546 image.
# loading no.1547 image.
# loading no.1548 image.
# loading no.1549 image.
# loading no.1550 image.
# loading no.1551 image.
# loading no.1552 image.
# loading no.1553 image.
# loading no.1554 image.
# loading no.1555 image.
# loading no.1556 image.
# loading no.1557 image.
# loading no.1558 image.
# loading no.1559 image.
# loading no.1560 image.
# loading no.1561 image.
# loading no.1562 image.
# loading no.1563 image.
# loading no.1564 image.
# loading no.1565 image.
# loading no.1566 image.
# loading no.1567 image.
# loading no.1568 image.
# loading no.1569 image.
# loading no.1570 image.
# loading no.1571 image.
# loading no.1572 image.
# loading no.1573 image.
# loading no.1574 image.
# loading no.1575 image.
# loading no.1576 image.
# loading no.1577 image.
# loading no.1578 image.
# loading no.1579 image.
# loading no.1580 image.
# loading no.1581 image.
# loading no.1582 image.
# loading no.1583 image.
# loading no.1584 image.
# loading no.1585 image.
# loading no.1586 image.
# loading no.1587 image.
# loading no.1588 image.
# loading no.1589 image.
# loading no.1590 image.
# loading no.1591 image.
# loading no.1592 image.
# loading no.1593 image.
# loading no.1594 image.
# loading no.1595 image.
# loading no.1596 image.
# loading no.1597 image.
# loading no.1598 image.
# loading no.1599 image.
# loading no.1600 image.
# loading no.1601 image.
# loading no.1602 image.
# loading no.1603 image.
# loading no.1604 image.
# loading no.1605 image.
# loading no.1606 image.
# loading no.1607 image.
# loading no.1608 image.
# loading no.1609 image.
# loading no.1610 image.
# loading no.1611 image.
# loading no.1612 image.
# loading no.1613 image.
# loading no.1614 image.
# loading no.1615 image.
# loading no.1616 image.
# loading no.1617 image.
# loading no.1618 image.
# loading no.1619 image.
# loading no.1620 image.
# loading no.1621 image.
# loading no.1622 image.
# loading no.1623 image.
# loading no.1624 image.
# loading no.1625 image.
# loading no.1626 image.
# loading no.1627 image.
# loading no.1628 image.
# loading no.1629 image.
# loading no.1630 image.
# loading no.1631 image.
# loading no.1632 image.
# loading no.1633 image.
# loading no.1634 image.
# loading no.1635 image.
# loading no.1636 image.
# loading no.1637 image.
# loading no.1638 image.
# loading no.1639 image.
# loading no.1640 image.
# loading no.1641 image.
# loading no.1642 image.
# loading no.1643 image.
# loading no.1644 image.
# loading no.1645 image.
# loading no.1646 image.
# loading no.1647 image.
# loading no.1648 image.
# loading no.1649 image.
# loading no.1650 image.
# loading no.1651 image.
# loading no.1652 image.
# loading no.1653 image.
# loading no.1654 image.
# loading no.1655 image.
# loading no.1656 image.
# loading no.1657 image.
# loading no.1658 image.
# loading no.1659 image.
# loading no.1660 image.
# loading no.1661 image.
# loading no.1662 image.
# loading no.1663 image.
# loading no.1664 image.
# loading no.1665 image.
# loading no.1666 image.
# loading no.1667 image.
# loading no.1668 image.
# loading no.1669 image.
# loading no.1670 image.
# loading no.1671 image.
# loading no.1672 image.
# loading no.1673 image.
# loading no.1674 image.
# loading no.1675 image.
# loading no.1676 image.
# loading no.1677 image.
# loading no.1678 image.
# loading no.1679 image.
# loading no.1680 image.
# loading no.1681 image.
# loading no.1682 image.
# loading no.1683 image.
# loading no.1684 image.
# loading no.1685 image.
# loading no.1686 image.
# loading no.1687 image.
# loading no.1688 image.
# loading no.1689 image.
# loading no.1690 image.
# loading no.1691 image.
# loading no.1692 image.
# loading no.1693 image.
# loading no.1694 image.
# loading no.1695 image.
# loading no.1696 image.
# loading no.1697 image.
# loading no.1698 image.
# loading no.1699 image.
# loading no.1700 image.
# loading no.1701 image.
# loading no.1702 image.
# loading no.1703 image.
# loading no.1704 image.
# loading no.1705 image.
# loading no.1706 image.
# loading no.1707 image.
# loading no.1708 image.
# loading no.1709 image.
# loading no.1710 image.
# loading no.1711 image.
# loading no.1712 image.
# loading no.1713 image.
# loading no.1714 image.
# loading no.1715 image.
# loading no.1716 image.
# loading no.1717 image.
# loading no.1718 image.
# loading no.1719 image.
# loading no.1720 image.
# loading no.1721 image.
# loading no.1722 image.
# loading no.1723 image.
# loading no.1724 image.
# loading no.1725 image.
# loading no.1726 image.
# loading no.1727 image.
# loading no.1728 image.
# loading no.1729 image.
# loading no.1730 image.
# loading no.1731 image.
# loading no.1732 image.
# loading no.1733 image.
# loading no.1734 image.
# loading no.1735 image.
# loading no.1736 image.
# loading no.1737 image.
# loading no.1738 image.
# loading no.1739 image.
# loading no.1740 image.
# loading no.1741 image.
# loading no.1742 image.
# loading no.1743 image.
# loading no.1744 image.
# loading no.1745 image.
# loading no.1746 image.
# loading no.1747 image.
# loading no.1748 image.
# loading no.1749 image.
# loading no.1750 image.
# loading no.1751 image.
# loading no.1752 image.
# loading no.1753 image.
# loading no.1754 image.
# loading no.1755 image.
# loading no.1756 image.
# loading no.1757 image.
# loading no.1758 image.
# loading no.1759 image.
# loading no.1760 image.
# loading no.1761 image.
# loading no.1762 image.
# loading no.1763 image.
# loading no.1764 image.
# loading no.1765 image.
# loading no.1766 image.
# loading no.1767 image.
# loading no.1768 image.
# loading no.1769 image.
# loading no.1770 image.
# loading no.1771 image.
# loading no.1772 image.
# loading no.1773 image.
# loading no.1774 image.
# loading no.1775 image.
# loading no.1776 image.
# loading no.1777 image.
# loading no.1778 image.
# loading no.1779 image.
# loading no.1780 image.
# loading no.1781 image.
# loading no.1782 image.
# loading no.1783 image.
# loading no.1784 image.
# loading no.1785 image.
# loading no.1786 image.
# loading no.1787 image.
# loading no.1788 image.
# loading no.1789 image.
# loading no.1790 image.
# loading no.1791 image.
# loading no.1792 image.
# loading no.1793 image.
# loading no.1794 image.
# loading no.1795 image.
# loading no.1796 image.
# loading no.1797 image.
# loading no.1798 image.
# loading no.1799 image.
# loading no.1800 image.
# loading no.1801 image.
# loading no.1802 image.
# loading no.1803 image.
# loading no.1804 image.
# loading no.1805 image.
# loading no.1806 image.
# loading no.1807 image.
# loading no.1808 image.
# loading no.1809 image.
# loading no.1810 image.
# loading no.1811 image.
# loading no.1812 image.
# loading no.1813 image.
# loading no.1814 image.
# loading no.1815 image.
# loading no.1816 image.
# loading no.1817 image.
# loading no.1818 image.
# loading no.1819 image.
# loading no.1820 image.
# loading no.1821 image.
# loading no.1822 image.
# loading no.1823 image.
# loading no.1824 image.
# loading no.1825 image.
# loading no.1826 image.
# loading no.1827 image.
# loading no.1828 image.
# loading no.1829 image.
# loading no.1830 image.
# loading no.1831 image.
# loading no.1832 image.
# loading no.1833 image.
# loading no.1834 image.
# loading no.1835 image.
# loading no.1836 image.
# loading no.1837 image.
# loading no.1838 image.
# loading no.1839 image.
# loading no.1840 image.
# loading no.1841 image.
# loading no.1842 image.
# loading no.1843 image.
# loading no.1844 image.
# loading no.1845 image.
# loading no.1846 image.
# loading no.1847 image.
# loading no.1848 image.
# loading no.1849 image.
# loading no.1850 image.
# loading no.1851 image.
# loading no.1852 image.
# loading no.1853 image.
# loading no.1854 image.
# loading no.1855 image.
# loading no.1856 image.
# loading no.1857 image.
# loading no.1858 image.
# loading no.1859 image.
# loading no.1860 image.
# loading no.1861 image.
# loading no.1862 image.
# loading no.1863 image.
# loading no.1864 image.
# loading no.1865 image.
# loading no.1866 image.
# loading no.1867 image.
# loading no.1868 image.
# loading no.1869 image.
# loading no.1870 image.
# loading no.1871 image.
# loading no.1872 image.
# loading no.1873 image.
# loading no.1874 image.
# loading no.1875 image.
# loading no.1876 image.
# loading no.1877 image.
# loading no.1878 image.
# loading no.1879 image.
# loading no.1880 image.
# loading no.1881 image.
# loading no.1882 image.
# loading no.1883 image.
# loading no.1884 image.
# loading no.1885 image.
# loading no.1886 image.
# loading no.1887 image.
# loading no.1888 image.
# loading no.1889 image.
# loading no.1890 image.
# loading no.1891 image.
# loading no.1892 image.
# loading no.1893 image.
# loading no.1894 image.
# loading no.1895 image.
# loading no.1896 image.
# loading no.1897 image.
# loading no.1898 image.
# loading no.1899 image.
# loading no.1900 image.
# loading no.1901 image.
# loading no.1902 image.
# loading no.1903 image.
# loading no.1904 image.
# loading no.1905 image.
# loading no.1906 image.
# loading no.1907 image.
# loading no.1908 image.
# loading no.1909 image.
# loading no.1910 image.
# loading no.1911 image.
# loading no.1912 image.
# loading no.1913 image.
# loading no.1914 image.
# loading no.1915 image.
# loading no.1916 image.
# loading no.1917 image.
# loading no.1918 image.
# loading no.1919 image.
# loading no.1920 image.
# loading no.1921 image.
# loading no.1922 image.
# loading no.1923 image.
# loading no.1924 image.
# loading no.1925 image.
# loading no.1926 image.
# loading no.1927 image.
# loading no.1928 image.
# loading no.1929 image.
# loading no.1930 image.
# loading no.1931 image.
# loading no.1932 image.
# loading no.1933 image.
# loading no.1934 image.
# loading no.1935 image.
# loading no.1936 image.
# loading no.1937 image.
# loading no.1938 image.
# loading no.1939 image.
# loading no.1940 image.
# loading no.1941 image.
# loading no.1942 image.
# loading no.1943 image.
# loading no.1944 image.
# loading no.1945 image.
# loading no.1946 image.
# loading no.1947 image.
# loading no.1948 image.
# loading no.1949 image.
# loading no.1950 image.
# loading no.1951 image.
# loading no.1952 image.
# loading no.1953 image.
# loading no.1954 image.
# loading no.1955 image.
# loading no.1956 image.
# loading no.1957 image.
# loading no.1958 image.
# loading no.1959 image.
# loading no.1960 image.
# loading no.1961 image.
# loading no.1962 image.
# loading no.1963 image.
# loading no.1964 image.
# loading no.1965 image.
# loading no.1966 image.
# loading no.1967 image.
# loading no.1968 image.
# loading no.1969 image.
# loading no.1970 image.
# loading no.1971 image.
# loading no.1972 image.
# loading no.1973 image.
# loading no.1974 image.
# loading no.1975 image.
# loading no.1976 image.
# loading no.1977 image.
# loading no.1978 image.
# loading no.1979 image.
# loading no.1980 image.
# loading no.1981 image.
# loading no.1982 image.
# loading no.1983 image.
# loading no.1984 image.
# loading no.1985 image.
# loading no.1986 image.
# loading no.1987 image.
# loading no.1988 image.
# loading no.1989 image.
# loading no.1990 image.
# loading no.1991 image.
# loading no.1992 image.
# loading no.1993 image.
# loading no.1994 image.
# loading no.1995 image.
# loading no.1996 image.
# loading no.1997 image.
# loading no.1998 image.
# loading no.1999 image.
# loading no.2000 image.
# loading no.2001 image.
# loading no.2002 image.
# loading no.2003 image.
# loading no.2004 image.
# loading no.2005 image.
# loading no.2006 image.
# loading no.2007 image.
# loading no.2008 image.
# loading no.2009 image.
# loading no.2010 image.
# loading no.2011 image.
# loading no.2012 image.
# loading no.2013 image.
# loading no.2014 image.
# loading no.2015 image.
# loading no.2016 image.
# loading no.2017 image.
# loading no.2018 image.
# loading no.2019 image.
# loading no.2020 image.
# loading no.2021 image.
# loading no.2022 image.
# loading no.2023 image.
# loading no.2024 image.
# loading no.2025 image.
# loading no.2026 image.
# loading no.2027 image.
# loading no.2028 image.
# loading no.2029 image.
# loading no.2030 image.
# loading no.2031 image.
# loading no.2032 image.
# loading no.2033 image.
# loading no.2034 image.
# loading no.2035 image.
# loading no.2036 image.
# loading no.2037 image.
# loading no.2038 image.
# loading no.2039 image.
# loading no.2040 image.
# loading no.2041 image.
# loading no.2042 image.
# loading no.2043 image.
# loading no.2044 image.
# loading no.2045 image.
# loading no.2046 image.
# loading no.2047 image.
# loading no.2048 image.
# loading no.2049 image.
# loading no.2050 image.
# loading no.2051 image.
# loading no.2052 image.
# loading no.2053 image.
# loading no.2054 image.
# loading no.2055 image.
# loading no.2056 image.
# loading no.2057 image.
# loading no.2058 image.
# loading no.2059 image.
# loading no.2060 image.
# loading no.2061 image.
# loading no.2062 image.
# loading no.2063 image.
# loading no.2064 image.
# loading no.2065 image.
# loading no.2066 image.
# loading no.2067 image.
# loading no.2068 image.
# loading no.2069 image.
# loading no.2070 image.
# loading no.2071 image.
# loading no.2072 image.
# loading no.2073 image.
# loading no.2074 image.
# loading no.2075 image.
# loading no.2076 image.
# loading no.2077 image.
# loading no.2078 image.
# loading no.2079 image.
# loading no.2080 image.
# loading no.2081 image.
# loading no.2082 image.
# loading no.2083 image.
# loading no.2084 image.
# loading no.2085 image.
# loading no.2086 image.
# loading no.2087 image.
# loading no.2088 image.
# loading no.2089 image.
# loading no.2090 image.
# loading no.2091 image.
# loading no.2092 image.
# loading no.2093 image.
# loading no.2094 image.
# loading no.2095 image.
# loading no.2096 image.
# loading no.2097 image.
# loading no.2098 image.
# loading no.2099 image.
# loading no.2100 image.
# loading no.2101 image.
# loading no.2102 image.
# loading no.2103 image.
# loading no.2104 image.
# loading no.2105 image.
# loading no.2106 image.
# loading no.2107 image.
# loading no.2108 image.
# loading no.2109 image.
# loading no.2110 image.
# loading no.2111 image.
# loading no.2112 image.
# loading no.2113 image.
# loading no.2114 image.
# loading no.2115 image.
# loading no.2116 image.
# loading no.2117 image.
# loading no.2118 image.
# loading no.2119 image.
# loading no.2120 image.
# loading no.2121 image.
# loading no.2122 image.
# loading no.2123 image.
# loading no.2124 image.
# loading no.2125 image.
# loading no.2126 image.
# loading no.2127 image.
# loading no.2128 image.
# loading no.2129 image.
# loading no.2130 image.
# loading no.2131 image.
# loading no.2132 image.
# loading no.2133 image.
# loading no.2134 image.
# ...
# loading no.13113 image.
# loading no.13114 image.
# loading no.13115 image.
# loading no.13116 image.
# loading no.13117 image.
# loading no.13118 image.
# loading no.13119 image.
# loading no.13120 image.
# loading no.13121 image.
# loading no.13122 image.
# loading no.13123 image.
# loading no.13124 image.
# loading no.13125 image.
# loading no.13126 image.
# loading no.13127 image.
# loading no.13128 image.
# loading no.13129 image.
# loading no.13130 image.
# loading no.13131 image.
# loading no.13132 image.
# loading no.13133 image.
# loading no.13134 image.
# loading no.13135 image.
# loading no.13136 image.
# loading no.13137 image.
# loading no.13138 image.
# loading no.13139 image.
# loading no.13140 image.
# loading no.13141 image.
# loading no.13142 image.
# loading no.13143 image.
# loading no.13144 image.
# loading no.13145 image.
# loading no.13146 image.
# loading no.13147 image.
# loading no.13148 image.
# loading no.13149 image.
# loading no.13150 image.
# loading no.13151 image.
# loading no.13152 image.
# loading no.13153 image.
# loading no.13154 image.
# loading no.13155 image.
# loading no.13156 image.
# loading no.13157 image.
# loading no.13158 image.
# loading no.13159 image.
# loading no.13160 image.
# loading no.13161 image.
# loading no.13162 image.
# loading no.13163 image.
# loading no.13164 image.
# loading no.13165 image.
# loading no.13166 image.
# loading no.13167 image.
# loading no.13168 image.
# loading no.13169 image.
# loading no.13170 image.
# loading no.13171 image.
# loading no.13172 image.
# loading no.13173 image.
# loading no.13174 image.
# loading no.13175 image.
# loading no.13176 image.
# loading no.13177 image.
# loading no.13178 image.
# loading no.13179 image.
# loading no.13180 image.
# loading no.13181 image.
# loading no.13182 image.
# loading no.13183 image.
# loading no.13184 image.
# loading no.13185 image.
# loading no.13186 image.
# loading no.13187 image.
# loading no.13188 image.
# loading no.13189 image.
# loading no.13190 image.
# loading no.13191 image.
# loading no.13192 image.
# loading no.13193 image.
# loading no.13194 image.
# loading no.13195 image.
# loading no.13196 image.
# loading no.13197 image.
# loading no.13198 image.
# loading no.13199 image.
# loading no.13200 image.
# loading no.13201 image.
# loading no.13202 image.
# loading no.13203 image.
# loading no.13204 image.
# loading no.13205 image.
# loading no.13206 image.
# loading no.13207 image.
# loading no.13208 image.
# loading no.13209 image.
# loading no.13210 image.
# loading no.13211 image.
# loading no.13212 image.
# loading no.13213 image.
# loading no.13214 image.
# loading no.13215 image.
# loading no.13216 image.
# loading no.13217 image.
# loading no.13218 image.
# loading no.13219 image.
# loading no.13220 image.
# loading no.13221 image.
# loading no.13222 image.
# loading no.13223 image.
# loading no.13224 image.
# loading no.13225 image.
# loading no.13226 image.
# loading no.13227 image.
# loading no.13228 image.
# loading no.13229 image.
# loading no.13230 image.
# loading no.13231 image.
# loading no.13232 image.
# loading no.13233 image.
# loading no.13234 image.
# loading no.13235 image.
# loading no.13236 image.
# loading no.13237 image.
# loading no.13238 image.
# loading no.13239 image.
# loading no.13240 image.
# loading no.13241 image.
# loading no.13242 image.
# loading no.13243 image.
# loading no.13244 image.
# loading no.13245 image.
# loading no.13246 image.
# loading no.13247 image.
# loading no.13248 image.
# loading no.13249 image.
# loading no.13250 image.
# loading no.13251 image.
# loading no.13252 image.
# loading no.13253 image.
# loading no.13254 image.
# loading no.13255 image.
# loading no.13256 image.
# loading no.13257 image.
# loading no.13258 image.
# loading no.13259 image.
# loading no.13260 image.
# loading no.13261 image.
# loading no.13262 image.
# loading no.13263 image.
# loading no.13264 image.
# loading no.13265 image.
# loading no.13266 image.
# loading no.13267 image.
# loading no.13268 image.
# loading no.13269 image.
# loading no.13270 image.
# loading no.13271 image.
# loading no.13272 image.
# loading no.13273 image.
# loading no.13274 image.
# loading no.13275 image.
# loading no.13276 image.
# loading no.13277 image.
# loading no.13278 image.
# loading no.13279 image.
# loading no.13280 image.
# loading no.13281 image.
# loading no.13282 image.
# loading no.13283 image.
# loading no.13284 image.
# loading no.13285 image.
# loading no.13286 image.
# loading no.13287 image.
# loading no.13288 image.
# loading no.13289 image.
# loading no.13290 image.
# loading no.13291 image.
# loading no.13292 image.
# loading no.13293 image.
# loading no.13294 image.
# loading no.13295 image.
# loading no.13296 image.
# loading no.13297 image.
# loading no.13298 image.
# loading no.13299 image.
# loading no.13300 image.
# loading no.13301 image.
# loading no.13302 image.
# loading no.13303 image.
# loading no.13304 image.
# loading no.13305 image.
# loading no.13306 image.
# loading no.13307 image.
# loading no.13308 image.
# loading no.13309 image.
# loading no.13310 image.
# loading no.13311 image.
# loading no.13312 image.
# loading no.13313 image.
# loading no.13314 image.
# loading no.13315 image.
# loading no.13316 image.
# loading no.13317 image.
# loading no.13318 image.
# loading no.13319 image.
# loading no.13320 image.
# loading no.13321 image.
# loading no.13322 image.
# loading no.13323 image.
# loading no.13324 image.
# loading no.13325 image.
# loading no.13326 image.
# loading no.13327 image.
# loading no.13328 image.
# loading no.13329 image.
# loading no.13330 image.
# loading no.13331 image.
# loading no.13332 image.
# loading no.13333 image.
# loading no.13334 image.
# loading no.13335 image.
# loading no.13336 image.
# loading no.13337 image.
# loading no.13338 image.
# loading no.13339 image.
# loading no.13340 image.
# loading no.13341 image.
# loading no.13342 image.
# loading no.13343 image.
# loading no.13344 image.
# loading no.13345 image.
# loading no.13346 image.
# loading no.13347 image.
# loading no.13348 image.
# loading no.13349 image.
# loading no.13350 image.
# loading no.13351 image.
# loading no.13352 image.
# loading no.13353 image.
# loading no.13354 image.
# loading no.13355 image.
# loading no.13356 image.
# loading no.13357 image.
# loading no.13358 image.
# loading no.13359 image.
# loading no.13360 image.
# loading no.13361 image.
# loading no.13362 image.
# loading no.13363 image.
# loading no.13364 image.
# loading no.13365 image.
# loading no.13366 image.
# loading no.13367 image.
# loading no.13368 image.
# loading no.13369 image.
# loading no.13370 image.
# loading no.13371 image.
# loading no.13372 image.
# loading no.13373 image.
# loading no.13374 image.
# loading no.13375 image.
# loading no.13376 image.
# loading no.13377 image.
# loading no.13378 image.
# loading no.13379 image.
# loading no.13380 image.
# loading no.13381 image.
# loading no.13382 image.
# loading no.13383 image.
# loading no.13384 image.
# loading no.13385 image.
# loading no.13386 image.
# loading no.13387 image.
# loading no.13388 image.
# loading no.13389 image.
# loading no.13390 image.
# loading no.13391 image.
# loading no.13392 image.
# loading no.13393 image.
# loading no.13394 image.
# loading no.13395 image.
# loading no.13396 image.
# loading no.13397 image.
# loading no.13398 image.
# loading no.13399 image.
# loading no.13400 image.
# loading no.13401 image.
# loading no.13402 image.
# loading no.13403 image.
# loading no.13404 image.
# loading no.13405 image.
# loading no.13406 image.
# loading no.13407 image.
# loading no.13408 image.
# loading no.13409 image.
# loading no.13410 image.
# loading no.13411 image.
# loading no.13412 image.
# loading no.13413 image.
# loading no.13414 image.
# loading no.13415 image.
# loading no.13416 image.
# loading no.13417 image.
# loading no.13418 image.
# loading no.13419 image.
# loading no.13420 image.
# loading no.13421 image.
# loading no.13422 image.
# loading no.13423 image.
# loading no.13424 image.
# loading no.13425 image.
# loading no.13426 image.
# loading no.13427 image.
# loading no.13428 image.
# loading no.13429 image.
# loading no.13430 image.
# loading no.13431 image.
# loading no.13432 image.
# loading no.13433 image.
# loading no.13434 image.
# loading no.13435 image.
# loading no.13436 image.
# loading no.13437 image.
# loading no.13438 image.
# loading no.13439 image.
# loading no.13440 image.
# loading no.13441 image.
# loading no.13442 image.
# loading no.13443 image.
# loading no.13444 image.
# loading no.13445 image.
# loading no.13446 image.
# loading no.13447 image.
# loading no.13448 image.
# loading no.13449 image.
# loading no.13450 image.
# loading no.13451 image.
# loading no.13452 image.
# loading no.13453 image.
# loading no.13454 image.
# loading no.13455 image.
# loading no.13456 image.
# loading no.13457 image.
# loading no.13458 image.
# loading no.13459 image.
# loading no.13460 image.
# loading no.13461 image.
# loading no.13462 image.
# loading no.13463 image.
# loading no.13464 image.
# loading no.13465 image.
# loading no.13466 image.
# loading no.13467 image.
# loading no.13468 image.
# loading no.13469 image.
# loading no.13470 image.
# loading no.13471 image.
# loading no.13472 image.
# loading no.13473 image.
# loading no.13474 image.
# loading no.13475 image.
# loading no.13476 image.
# loading no.13477 image.
# loading no.13478 image.
# loading no.13479 image.
# loading no.13480 image.
# loading no.13481 image.
# loading no.13482 image.
# loading no.13483 image.
# loading no.13484 image.
# loading no.13485 image.
# loading no.13486 image.
# loading no.13487 image.
# loading no.13488 image.
# loading no.13489 image.
# loading no.13490 image.
# loading no.13491 image.
# loading no.13492 image.
# loading no.13493 image.
# loading no.13494 image.
# loading no.13495 image.
# loading no.13496 image.
# loading no.13497 image.
# loading no.13498 image.
# loading no.13499 image.
# loading no.13500 image.
# loading no.13501 image.
# loading no.13502 image.
# loading no.13503 image.
# loading no.13504 image.
# loading no.13505 image.
# loading no.13506 image.
# loading no.13507 image.
# loading no.13508 image.
# loading no.13509 image.
# loading no.13510 image.
# loading no.13511 image.
# loading no.13512 image.
# loading no.13513 image.
# loading no.13514 image.
# loading no.13515 image.
# loading no.13516 image.
# loading no.13517 image.
# loading no.13518 image.
# loading no.13519 image.
# loading no.13520 image.
# loading no.13521 image.
# loading no.13522 image.
# loading no.13523 image.
# loading no.13524 image.
# loading no.13525 image.
# loading no.13526 image.
# loading no.13527 image.
# loading no.13528 image.
# loading no.13529 image.
# loading no.13530 image.
# loading no.13531 image.
# loading no.13532 image.
# loading no.13533 image.
# loading no.13534 image.
# loading no.13535 image.
# loading no.13536 image.
# loading no.13537 image.
# loading no.13538 image.
# loading no.13539 image.
# loading no.13540 image.
# loading no.13541 image.
# loading no.13542 image.
# loading no.13543 image.
# loading no.13544 image.
# loading no.13545 image.
# loading no.13546 image.
# loading no.13547 image.
# loading no.13548 image.
# loading no.13549 image.
# loading no.13550 image.
# loading no.13551 image.
# loading no.13552 image.
# loading no.13553 image.
# loading no.13554 image.
# loading no.13555 image.
# loading no.13556 image.
# loading no.13557 image.
# loading no.13558 image.
# loading no.13559 image.
# loading no.13560 image.
# loading no.13561 image.
# loading no.13562 image.
# loading no.13563 image.
# loading no.13564 image.
# loading no.13565 image.
# loading no.13566 image.
# loading no.13567 image.
# loading no.13568 image.
# loading no.13569 image.
# loading no.13570 image.
# loading no.13571 image.
# loading no.13572 image.
# loading no.13573 image.
# loading no.13574 image.
# loading no.13575 image.
# loading no.13576 image.
# loading no.13577 image.
# loading no.13578 image.
# loading no.13579 image.
# loading no.13580 image.
# loading no.13581 image.
# loading no.13582 image.
# loading no.13583 image.
# loading no.13584 image.
# loading no.13585 image.
# loading no.13586 image.
# loading no.13587 image.
# loading no.13588 image.
# loading no.13589 image.
# loading no.13590 image.
# loading no.13591 image.
# loading no.13592 image.
# loading no.13593 image.
# loading no.13594 image.
# loading no.13595 image.
# loading no.13596 image.
# loading no.13597 image.
# loading no.13598 image.
# loading no.13599 image.
# loading no.13600 image.
# loading no.13601 image.
# loading no.13602 image.
# loading no.13603 image.
# loading no.13604 image.
# loading no.13605 image.
# loading no.13606 image.
# loading no.13607 image.
# loading no.13608 image.
# loading no.13609 image.
# loading no.13610 image.
# loading no.13611 image.
# loading no.13612 image.
# loading no.13613 image.
# loading no.13614 image.
# loading no.13615 image.
# loading no.13616 image.
# loading no.13617 image.
# loading no.13618 image.
# loading no.13619 image.
# loading no.13620 image.
# loading no.13621 image.
# loading no.13622 image.
# loading no.13623 image.
# loading no.13624 image.
# loading no.13625 image.
# loading no.13626 image.
# loading no.13627 image.
# loading no.13628 image.
# loading no.13629 image.
# loading no.13630 image.
# loading no.13631 image.
# loading no.13632 image.
# loading no.13633 image.
# loading no.13634 image.
# loading no.13635 image.
# loading no.13636 image.
# loading no.13637 image.
# loading no.13638 image.
# loading no.13639 image.
# loading no.13640 image.
# loading no.13641 image.
# loading no.13642 image.
# loading no.13643 image.
# loading no.13644 image.
# loading no.13645 image.
# loading no.13646 image.
# loading no.13647 image.
# loading no.13648 image.
# loading no.13649 image.
# loading no.13650 image.
# loading no.13651 image.
# loading no.13652 image.
# loading no.13653 image.
# loading no.13654 image.
# loading no.13655 image.
# loading no.13656 image.
# loading no.13657 image.
# loading no.13658 image.
# loading no.13659 image.
# loading no.13660 image.
# loading no.13661 image.
# loading no.13662 image.
# loading no.13663 image.
# loading no.13664 image.
# loading no.13665 image.
# loading no.13666 image.
# loading no.13667 image.
# loading no.13668 image.
# loading no.13669 image.
# loading no.13670 image.
# loading no.13671 image.
# loading no.13672 image.
# loading no.13673 image.
# loading no.13674 image.
# loading no.13675 image.
# loading no.13676 image.
# loading no.13677 image.
# loading no.13678 image.
# loading no.13679 image.
# loading no.13680 image.
# loading no.13681 image.
# loading no.13682 image.
# loading no.13683 image.
# loading no.13684 image.
# loading no.13685 image.
# loading no.13686 image.
# loading no.13687 image.
# loading no.13688 image.
# loading no.13689 image.
# loading no.13690 image.
# loading no.13691 image.
# loading no.13692 image.
# loading no.13693 image.
# loading no.13694 image.
# loading no.13695 image.
# loading no.13696 image.
# loading no.13697 image.
# loading no.13698 image.
# loading no.13699 image.
# loading no.13700 image.
# loading no.13701 image.
# loading no.13702 image.
# loading no.13703 image.
# loading no.13704 image.
# loading no.13705 image.
# loading no.13706 image.
# loading no.13707 image.
# loading no.13708 image.
# loading no.13709 image.
# loading no.13710 image.
# loading no.13711 image.
# loading no.13712 image.
# loading no.13713 image.
# loading no.13714 image.
# loading no.13715 image.
# loading no.13716 image.
# loading no.13717 image.
# loading no.13718 image.
# loading no.13719 image.
# loading no.13720 image.
# loading no.13721 image.
# loading no.13722 image.
# loading no.13723 image.
# loading no.13724 image.
# loading no.13725 image.
# loading no.13726 image.
# loading no.13727 image.
# loading no.13728 image.
# loading no.13729 image.
# loading no.13730 image.
# loading no.13731 image.
# loading no.13732 image.
# loading no.13733 image.
# loading no.13734 image.
# loading no.13735 image.
# loading no.13736 image.
# loading no.13737 image.
# loading no.13738 image.
# loading no.13739 image.
# loading no.13740 image.
# loading no.13741 image.
# loading no.13742 image.
# loading no.13743 image.
# loading no.13744 image.
# loading no.13745 image.
# loading no.13746 image.
# loading no.13747 image.
# loading no.13748 image.
# loading no.13749 image.
# loading no.13750 image.
# loading no.13751 image.
# loading no.13752 image.
# loading no.13753 image.
# loading no.13754 image.
# loading no.13755 image.
# loading no.13756 image.
# loading no.13757 image.
# loading no.13758 image.
# loading no.13759 image.
# loading no.13760 image.
# loading no.13761 image.
# loading no.13762 image.
# loading no.13763 image.
# loading no.13764 image.
# loading no.13765 image.
# loading no.13766 image.
# loading no.13767 image.
# loading no.13768 image.
# loading no.13769 image.
# loading no.13770 image.
# loading no.13771 image.
# loading no.13772 image.
# loading no.13773 image.
# loading no.13774 image.
# loading no.13775 image.
# loading no.13776 image.
# loading no.13777 image.
# loading no.13778 image.

# %%
x1 = np.concatenate([x for x in imgs]) # concatenate

# %%
y1=np.ones(x1.shape[0])

# %%
y1
# Out:
# array([1., 1., 1., ..., 1., 1., 1.])

# %%
X = np.vstack([x0,x1])

# %%
X.shape
# Out:
# (27558, 28, 28, 3)

# %%
y = np.concatenate([y0,y1])

# %%
y
# Out:
# array([0., 0., 0., ..., 1., 1., 1.])

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
X_train = X_train / 255.0
X_test = X_test / 255.0

# %%
epochs_num = 20
batch_size = 100
steps_per_epoch_num = X_train.shape[0] // batch_size

# %%
train_dataset = tf.data.Dataset.from_tensor_slices((X_train, y_train))
test_dataset = tf.data.Dataset.from_tensor_slices((X_test, y_test))

# %%
train_dataset = train_dataset.batch(batch_size=epochs_num)
train_dataset = train_dataset.repeat(count=epochs_num) # repeat should >= epochs_num
train_dataset = train_dataset.shuffle(buffer_size=10)

# %%
test_dataset = test_dataset.batch(batch_size=epochs_num)
# test_dataset = test_dataset.batch(batch_size=100)
#test_dataset = test_dataset.repeat(count=1)

# %%
classifier = tf.keras.models.Sequential()
classifier.add(tf.keras.layers.Conv2D(8, kernel_size=(3, 3),
                 activation='relu',
                 input_shape=(28,28,3)))
classifier.add(tf.keras.layers.Conv2D(16, (3, 3), activation='relu'))
classifier.add(tf.keras.layers.MaxPooling2D(pool_size=(2, 2)))
classifier.add(tf.keras.layers.Flatten())
classifier.add(tf.keras.layers.Dense(64, activation='relu'))
classifier.add(tf.keras.layers.Dense(1, activation='sigmoid'))

# %%
classifier.compile(optimizer ='adam', loss = 'binary_crossentropy', metrics = [tf.keras.metrics.Accuracy()])

# %%
classifier.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 26, 26, 8)         224
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 24, 24, 16)        1168
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 12, 12, 16)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 2304)              0
# _________________________________________________________________
# dense (Dense)                (None, 64)                147520
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 148,977
# Trainable params: 148,977
# Non-trainable params: 0
# _________________________________________________________________

# %%
classifier.fit(
        train_dataset,
        steps_per_epoch= steps_per_epoch_num,
        epochs=epochs_num,
        validation_data = test_dataset
)
# Out:
# Train for 184 steps, validate for 455 steps
# Epoch 1/20
# 184/184 [==============================] - 4s 22ms/step - loss: 0.6390 - accuracy: 0.0000e+00 - val_loss: 0.6029 - val_accuracy: 0.0000e+00
# Epoch 2/20
# 184/184 [==============================] - 3s 14ms/step - loss: 0.5795 - accuracy: 0.0000e+00 - val_loss: 0.5558 - val_accuracy: 0.0000e+00
# Epoch 3/20
# 184/184 [==============================] - 3s 15ms/step - loss: 0.5531 - accuracy: 0.0000e+00 - val_loss: 0.5330 - val_accuracy: 0.0000e+00
# Epoch 4/20
# 184/184 [==============================] - 3s 16ms/step - loss: 0.4732 - accuracy: 0.0000e+00 - val_loss: 0.4172 - val_accuracy: 0.0000e+00
# Epoch 5/20
# 184/184 [==============================] - 3s 16ms/step - loss: 0.4043 - accuracy: 0.0000e+00 - val_loss: 0.3882 - val_accuracy: 0.0000e+00
# Epoch 6/20
# 184/184 [==============================] - 3s 16ms/step - loss: 0.3162 - accuracy: 0.0000e+00 - val_loss: 0.2898 - val_accuracy: 0.0000e+00
# Epoch 7/20
# 184/184 [==============================] - 3s 16ms/step - loss: 0.2750 - accuracy: 0.0000e+00 - val_loss: 0.2616 - val_accuracy: 0.0000e+00
# Epoch 8/20
# 184/184 [==============================] - 3s 16ms/step - loss: 0.2548 - accuracy: 0.0000e+00 - val_loss: 0.2647 - val_accuracy: 0.0000e+00
# Epoch 9/20
# 184/184 [==============================] - 3s 16ms/step - loss: 0.2502 - accuracy: 0.0000e+00 - val_loss: 0.2245 - val_accuracy: 0.0000e+00
# Epoch 10/20
# 184/184 [==============================] - 3s 16ms/step - loss: 0.2275 - accuracy: 0.0000e+00 - val_loss: 0.2161 - val_accuracy: 0.0000e+00
# Epoch 11/20
# 184/184 [==============================] - 3s 16ms/step - loss: 0.1981 - accuracy: 0.0000e+00 - val_loss: 0.2364 - val_accuracy: 1.0995e-04
# Epoch 12/20
# 184/184 [==============================] - 3s 17ms/step - loss: 0.1857 - accuracy: 2.7174e-04 - val_loss: 0.1959 - val_accuracy: 1.0995e-04
# Epoch 13/20
# 184/184 [==============================] - 3s 17ms/step - loss: 0.1788 - accuracy: 8.1522e-04 - val_loss: 0.1923 - val_accuracy: 4.3980e-04
# Epoch 14/20
# 184/184 [==============================] - 3s 18ms/step - loss: 0.1810 - accuracy: 2.7174e-04 - val_loss: 0.2044 - val_accuracy: 2.1990e-04
# Epoch 15/20
# 184/184 [==============================] - 4s 20ms/step - loss: 0.1706 - accuracy: 2.7174e-04 - val_loss: 0.1864 - val_accuracy: 6.5970e-04
# Epoch 16/20
# 184/184 [==============================] - 4s 23ms/step - loss: 0.1609 - accuracy: 0.0000e+00 - val_loss: 0.1815 - val_accuracy: 6.5970e-04
# Epoch 17/20
# 184/184 [==============================] - 5s 25ms/step - loss: 0.1453 - accuracy: 8.1522e-04 - val_loss: 0.1882 - val_accuracy: 0.0012
# Epoch 18/20
# 184/184 [==============================] - 5s 27ms/step - loss: 0.1637 - accuracy: 0.0016 - val_loss: 0.1636 - val_accuracy: 0.0011
# Epoch 19/20
# 184/184 [==============================] - 5s 29ms/step - loss: 0.1584 - accuracy: 0.0019 - val_loss: 0.1606 - val_accuracy: 0.0029
# Epoch 20/20
# 184/184 [==============================] - 6s 31ms/step - loss: 0.1341 - accuracy: 0.0016 - val_loss: 0.1618 - val_accuracy: 0.0020

# %%
print(tf.__version__)
# Out:
# 2.0.0
